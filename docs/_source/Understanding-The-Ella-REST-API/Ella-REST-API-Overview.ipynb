# %% [markdown]
# # The ELLA REST API
#
# Ella has a large REST API that can be used to fetch all kinds of data.

# %%
import requests
import json
from pprint import pprint

# %% [markdown]
# ## Querying the ELLA API
#
# In order to get the REST API you'll need to know what port Ella is running on.
#
# This can get a bit tricky because you need to pay attention to whether or not you are running within the docker container or the port exposed outside.
#
# In this case I am running in the jupyterhub notebook provided within the `ella-admin` jupyterhub stack. This means that I am using the network created by docker, so I query ella using the service name `ella-web` on port `5000`.
#
# (For the sake of brevity I got rid of some of the variables in the ella-web service.)
#
# ```yaml
#   ella-web:
#     image: dabbleofdevops/ella:1.11.1
#     ports:
#       # External:Internal
#       # Expose the port running in the container as 5000 to my localhost as 5001
#       - 5001:5000
# ```
#
# ### Query Internally from within a Docker Container
#
# You could exec (`docker-compose exec -f local.yml ella-web` or `docker-compose exec -f local.yml jupyter`) into a docker container, or use the notebook to query the Ella API. If you do that you should use the url `http://{service-name}/{internal-port}`.
#
# ### Query Externally from the Docker Host
#
# If you want to run this command externally, such as if you are using Postman, you need to use the external url. `http://localhost:5001` or `http://{ip-of-server}/{external-port}`.

# %%
response = requests.get('http://ella-web:5000/api/v1/specs')
content = response.content.decode('utf-8')
api_spec_data = json.loads(content)

print('--------------------------')
pprint(api_spec_data.keys())
print('--------------------------')
pprint(api_spec_data['definitions'].keys())
print('--------------------------')
pprint(list(api_spec_data['paths'].keys()))
# Out:
# --------------------------
# dict_keys(['info', 'paths', 'tags', 'swagger', 'definitions', 'parameters'])
# --------------------------
# dict_keys(['Analysis', 'AnalysisInterpretation', 'AlleleInterpretation', 'Interpretation', 'Allele', 'Reference', 'ReferenceAssessment', 'AlleleAssessment', 'AlleleAssessmentInput', 'AlleleReport', 'User', 'Classification', 'Rule', 'Genepanel', 'Annotation', 'CustomAnnotation', 'Genotype'])
# --------------------------
# ['/api/v1/acmg/alleles/',
#  '/api/v1/acmg/classifications/',
#  '/api/v1/alleles/',
#  '/api/v1/alleles/by-gene/',
#  '/api/v1/alleles/{allele_id}/analyses/',
#  '/api/v1/alleleassessments/{aa_id}/',
#  '/api/v1/alleleassessments/',
#  '/api/v1/allelereports/',
#  '/api/v1/allelereports/{ar_id}/',
#  '/api/v1/analyses/',
#  '/api/v1/analyses/{analysis_id}/',
#  '/api/v1/broadcasts/',
#  '/api/v1/customannotations/',
#  '/api/v1/config/',
#  '/api/v1/filterconfigs/{filterconfig_id}',
#  '/api/v1/geneassessments/',
#  '/api/v1/genepanels/',
#  '/api/v1/genepanels/{name}/{version}/',
#  '/api/v1/genepanels/{name}/{version}/stats/',
#  '/api/v1/references/',
#  '/api/v1/referenceassessments/{ra_id}/',
#  '/api/v1/referenceassessments/',
#  '/api/v1/search/',
#  '/api/v1/search/options/',
#  '/api/v1/users/',
#  '/api/v1/users/{user_id}/',
#  '/api/v1/overviews/alleles/',
#  '/api/v1/overviews/alleles/finalized/',
#  '/api/v1/overviews/analyses/',
#  '/api/v1/overviews/analyses/finalized/',
#  '/api/v1/overviews/userstats/',
#  '/api/v1/import/service/jobs/{id}/',
#  '/api/v1/import/service/jobs/',
#  '/api/v1/import/service/running/',
#  '/api/v1/import/service/samples/',
#  '/api/v1/workflows/alleles/{allele_id}/genepanels/{gp_name}/{gp_version}/',
#  '/api/v1/workflows/alleles/{allele_id}/genepanels/',
#  '/api/v1/workflows/alleles/{allele_id}/interpretations/',
#  '/api/v1/workflows/alleles/{allele_id}/interpretations/{interpretation_id}/',
#  '/api/v1/workflows/alleles/{allele_id}/interpretations/{interpretation_id}/alleles/',
#  '/api/v1/workflows/alleles/{allele_id}/actions/start/',
#  '/api/v1/workflows/alleles/{allele_id}/actions/markinterpretation/',
#  '/api/v1/workflows/alleles/{allele_id}/actions/markreview/',
#  '/api/v1/workflows/alleles/{allele_id}/actions/finalize/',
#  '/api/v1/workflows/alleles/{allele_id}/actions/finalizeallele/',
#  '/api/v1/workflows/alleles/{allele_id}/actions/override/',
#  '/api/v1/workflows/alleles/{allele_id}/actions/reopen/',
#  '/api/v1/workflows/alleles/{allele_id}/collisions/',
#  '/api/v1/workflows/alleles/{allele_id}/logs/',
#  '/api/v1/workflows/alleles/{allele_id}/logs/{log_id}/',
#  '/api/v1/workflows/analyses/{analysis_id}/stats/',
#  '/api/v1/workflows/analyses/{analysis_id}/interpretations/',
#  '/api/v1/workflows/analyses/{analysis_id}/genepanels/{gp_name}/{gp_version}/',
#  '/api/v1/workflows/analyses/{analysis_id}/interpretations/{interpretation_id}/',
#  '/api/v1/workflows/analyses/{analysis_id}/interpretations/{interpretation_id}/finishallowed',
#  '/api/v1/workflows/analyses/{analysis_id}/interpretations/{interpretation_id}/filteredalleles/',
#  '/api/v1/workflows/analyses/{analysis_id}/interpretations/{interpretation_id}/alleles/',
#  '/api/v1/workflows/analyses/{analysis_id}/actions/start/',
#  '/api/v1/workflows/analyses/{analysis_id}/actions/marknotready/',
#  '/api/v1/workflows/analyses/{analysis_id}/actions/markinterpretation/',
#  '/api/v1/workflows/analyses/{analysis_id}/actions/markreview/',
#  '/api/v1/workflows/analyses/{analysis_id}/actions/markmedicalreview/',
#  '/api/v1/workflows/analyses/{analysis_id}/actions/finalize/',
#  '/api/v1/workflows/analyses/{analysis_id}/actions/finalizeallele/',
#  '/api/v1/workflows/analyses/{analysis_id}/actions/override/',
#  '/api/v1/workflows/analyses/{analysis_id}/actions/reopen/',
#  '/api/v1/workflows/analyses/{analysis_id}/collisions/',
#  '/api/v1/workflows/analyses/{analysis_id}/logs/',
#  '/api/v1/workflows/analyses/{analysis_id}/logs/{log_id}/',
#  '/api/v1/workflows/analyses/{analysis_id}/filterconfigs/',
#  '/api/v1/users/actions/login/',
#  '/api/v1/users/actions/logout/',
#  '/api/v1/users/actions/changepassword/',
#  '/api/v1/users/currentuser/',
#  '/api/v1/attachments/upload/',
#  '/api/v1/attachments/',
#  '/api/v1/igv/{filename}',
#  '/api/v1/igv/search/',
#  '/api/v1/igv/genepanel/{gp_name}/{gp_version}/',
#  '/api/v1/igv/classifications/',
#  '/api/v1/igv/variants/{analysis_id}/',
#  '/api/v1/igv/tracks/{analysis_id}/',
#  '/api/v1/igv/tracks/global/{filename}',
#  '/api/v1/igv/tracks/usergroups/{usergroup_id}/{filename}',
#  '/api/v1/igv/tracks/analyses/{analysis_id}/{filename}']

# %% [markdown]
# ## Authenticating Against the REST API
#
# In order to authenticate against the REST API we'll have to pass in our username and password. If you ran the dev stack as
#
# ```bash
# make dev
# make load
# ```
#
# You should already have a test user setup.
#
# (Please note that the dev stack is for dev purposes only and you should change your own usernames and passwords!)
#
# Once we've authenticated we should have a cookie called 'AuthenticationToken'. Using the Python Requests session this is saved for us. Otherwise you will have to add the token to your cookies manually.

# %%
session = requests.Session()

url = 'http://ella-web:5000'
user_data = {"username": "testuser1", "password": "Password#123"}
session.post('{}/api/v1/users/actions/login/'.format(url), json=user_data)
print(session.cookies.get_dict())
# Out:
# {'AuthenticationToken': '0b5a3cc5679cd7bcdb82206b46b4d21c6546b1ba835568e44047fc5910385a7c'}

# %% [markdown]
# Now that we're authenticated we can start running queries!

# %% [markdown]
# ## Run Authenticated Queries

# %%
response = session.get('{}/api/v1/workflows/analyses/2/interpretations/2/'.format(url))
print(session.cookies.get_dict())
# Out:
# {'AuthenticationToken': '0b5a3cc5679cd7bcdb82206b46b4d21c6546b1ba835568e44047fc5910385a7c'}

# %%
pprint(json.loads(response.content.decode('utf-8')))
# Out:
# {'date_last_update': '2020-11-28T06:44:25.638124+00:00',
#  'finalized': True,
#  'genepanel_name': 'HBOCUTV',
#  'genepanel_version': 'v01',
#  'id': 2,
#  'state': {'allele': {'3': {'allele_id': 3,
#                             'alleleassessment': {'allele_id': 3,
#                                                  'evaluation': {'acmg': {'suggested': [{'code': 'REQ_GP_last_exon_not_important',
#                                                                                         'match': ['LENI'],
#                                                                                         'op': '$in',
#                                                                                         'source': 'genepanel.last_exon_important'},
#                                                                                        {'code': 'REQ_GP_LOF_missense',
#                                                                                         'match': ['ANY'],
#                                                                                         'op': '$in',
#                                                                                         'source': 'genepanel.disease_mode'},
#                                                                                        {'code': 'REQ_not_in_last_exon',
#                                                                                         'match': ['no'],
#                                                                                         'op': '$in',
#                                                                                         'source': 'transcript.in_last_exon'},
#                                                                                        {'code': 'REQ_null_variant',
#                                                                                         'match': ['stop_gained'],
#                                                                                         'op': '$in',
#                                                                                         'source': 'transcript.consequences'},
#                                                                                        {'code': 'REQ_no_freq',
#                                                                                         'match': ['null_freq'],
#                                                                                         'op': '$in',
#                                                                                         'source': 'frequencies.commonness'},
#                                                                                        {'code': 'PVS1',
#                                                                                         'match': None,
#                                                                                         'op': None,
#                                                                                         'source': None},
#                                                                                        {'code': 'PPxPM2',
#                                                                                         'match': None,
#                                                                                         'op': None,
#                                                                                         'source': None}]}},
#                                                  'reuse': True,
#                                                  'reuseCheckedId': 1},
#                             'allelereport': {'copiedFromId': 1,
#                                              'evaluation': {'comment': ''}},
#                             'analysis': {'comment': '',
#                                          'notrelevant': None,
#                                          'verification': 'verified'},
#                             'referenceassessments': [],
#                             'report': {'included': True},
#                             'workflow': {'reviewed': True}},
#                       '4': {'allele_id': 4,
#                             'alleleassessment': {'allele_id': 4,
#                                                  'evaluation': {'acmg': {'suggested': [{'code': 'REQ_GP_last_exon_not_important',
#                                                                                         'match': ['LENI'],
#                                                                                         'op': '$in',
#                                                                                         'source': 'genepanel.last_exon_important'},
#                                                                                        {'code': 'REQ_GP_LOF_missense',
#                                                                                         'match': ['ANY'],
#                                                                                         'op': '$in',
#                                                                                         'source': 'genepanel.disease_mode'},
#                                                                                        {'code': 'REQ_not_in_last_exon',
#                                                                                         'match': ['no'],
#                                                                                         'op': '$in',
#                                                                                         'source': 'transcript.in_last_exon'},
#                                                                                        {'code': 'REQ_null_variant',
#                                                                                         'match': ['frameshift_variant'],
#                                                                                         'op': '$in',
#                                                                                         'source': 'transcript.consequences'},
#                                                                                        {'code': 'REQ_no_freq',
#                                                                                         'match': ['null_freq'],
#                                                                                         'op': '$in',
#                                                                                         'source': 'frequencies.commonness'},
#                                                                                        {'code': 'PVS1',
#                                                                                         'match': None,
#                                                                                         'op': None,
#                                                                                         'source': None},
#                                                                                        {'code': 'PPxPM2',
#                                                                                         'match': None,
#                                                                                         'op': None,
#                                                                                         'source': None}]}},
#                                                  'reuse': True,
#                                                  'reuseCheckedId': 2},
#                             'allelereport': {'copiedFromId': 2,
#                                              'evaluation': {'comment': ''}},
#                             'analysis': {'comment': '',
#                                          'notrelevant': None,
#                                          'verification': 'verified'},
#                             'referenceassessments': [],
#                             'report': {'included': True},
#                             'workflow': {'reviewed': True}},
#                       '5': {'allele_id': 5,
#                             'alleleassessment': {'allele_id': 5,
#                                                  'evaluation': {'acmg': {'suggested': [{'code': 'REQ_GP_last_exon_not_important',
#                                                                                         'match': ['LENI'],
#                                                                                         'op': '$in',
#                                                                                         'source': 'genepanel.last_exon_important'},
#                                                                                        {'code': 'REQ_GP_LOF_missense',
#                                                                                         'match': ['ANY'],
#                                                                                         'op': '$in',
#                                                                                         'source': 'genepanel.disease_mode'},
#                                                                                        {'code': 'REQ_not_in_last_exon',
#                                                                                         'match': ['no'],
#                                                                                         'op': '$in',
#                                                                                         'source': 'transcript.in_last_exon'},
#                                                                                        {'code': 'REQ_null_variant',
#                                                                                         'match': ['splice_donor_variant'],
#                                                                                         'op': '$in',
#                                                                                         'source': 'transcript.consequences'},
#                                                                                        {'code': 'REQ_no_freq',
#                                                                                         'match': ['null_freq'],
#                                                                                         'op': '$in',
#                                                                                         'source': 'frequencies.commonness'},
#                                                                                        {'code': 'PVS1',
#                                                                                         'match': None,
#                                                                                         'op': None,
#                                                                                         'source': None},
#                                                                                        {'code': 'PPxPM2',
#                                                                                         'match': None,
#                                                                                         'op': None,
#                                                                                         'source': None}]}},
#                                                  'reuse': True,
#                                                  'reuseCheckedId': 3},
#                             'allelereport': {'copiedFromId': 3,
#                                              'evaluation': {'comment': ''}},
#                             'analysis': {'comment': '',
#                                          'notrelevant': None,
#                                          'verification': 'verified'},
#                             'referenceassessments': [],
#                             'report': {'included': True},
#                             'workflow': {'reviewed': True}},
#                       '6': {'allele_id': 6,
#                             'alleleassessment': {'allele_id': 6,
#                                                  'evaluation': {'acmg': {'suggested': [{'code': 'REQ_GP_last_exon_not_important',
#                                                                                         'match': ['LENI'],
#                                                                                         'op': '$in',
#                                                                                         'source': 'genepanel.last_exon_important'},
#                                                                                        {'code': 'REQ_GP_LOF_missense',
#                                                                                         'match': ['ANY'],
#                                                                                         'op': '$in',
#                                                                                         'source': 'genepanel.disease_mode'},
#                                                                                        {'code': 'REQ_missense',
#                                                                                         'match': ['missense_variant'],
#                                                                                         'op': '$in',
#                                                                                         'source': 'transcript.consequences'},
#                                                                                        {'code': 'REQ_not_in_last_exon',
#                                                                                         'match': ['no'],
#                                                                                         'op': '$in',
#                                                                                         'source': 'transcript.in_last_exon'}]}},
#                                                  'reuse': True,
#                                                  'reuseCheckedId': 4},
#                             'allelereport': {'copiedFromId': 4,
#                                              'evaluation': {'comment': ''}},
#                             'analysis': {'comment': '',
#                                          'notrelevant': None,
#                                          'verification': 'verified'},
#                             'referenceassessments': [],
#                             'report': {'included': False},
#                             'workflow': {'reviewed': True}},
#                       '7': {'allele_id': 7,
#                             'alleleassessment': {'allele_id': 7,
#                                                  'evaluation': {'acmg': {'suggested': [{'code': 'REQ_GP_last_exon_not_important',
#                                                                                         'match': ['LENI'],
#                                                                                         'op': '$in',
#                                                                                         'source': 'genepanel.last_exon_important'},
#                                                                                        {'code': 'REQ_GP_LOF_missense',
#                                                                                         'match': ['ANY'],
#                                                                                         'op': '$in',
#                                                                                         'source': 'genepanel.disease_mode'},
#                                                                                        {'code': 'REQ_not_in_last_exon',
#                                                                                         'match': ['no'],
#                                                                                         'op': '$in',
#                                                                                         'source': 'transcript.in_last_exon'},
#                                                                                        {'code': 'REQ_null_variant',
#                                                                                         'match': ['stop_gained'],
#                                                                                         'op': '$in',
#                                                                                         'source': 'transcript.consequences'},
#                                                                                        {'code': 'REQ_no_freq',
#                                                                                         'match': ['null_freq'],
#                                                                                         'op': '$in',
#                                                                                         'source': 'frequencies.commonness'},
#                                                                                        {'code': 'PVS1',
#                                                                                         'match': None,
#                                                                                         'op': None,
#                                                                                         'source': None},
#                                                                                        {'code': 'PPxPM2',
#                                                                                         'match': None,
#                                                                                         'op': None,
#                                                                                         'source': None}]}},
#                                                  'reuse': True,
#                                                  'reuseCheckedId': 5},
#                             'allelereport': {'copiedFromId': 5,
#                                              'evaluation': {'comment': ''}},
#                             'analysis': {'comment': '',
#                                          'notrelevant': None,
#                                          'verification': 'verified'},
#                             'referenceassessments': [],
#                             'report': {'included': True},
#                             'workflow': {'reviewed': True}},
#                       '8': {'allele_id': 8,
#                             'alleleassessment': {'allele_id': 8,
#                                                  'evaluation': {'acmg': {'suggested': [{'code': 'REQ_GP_last_exon_not_important',
#                                                                                         'match': ['LENI'],
#                                                                                         'op': '$in',
#                                                                                         'source': 'genepanel.last_exon_important'},
#                                                                                        {'code': 'REQ_GP_LOF_missense',
#                                                                                         'match': ['ANY'],
#                                                                                         'op': '$in',
#                                                                                         'source': 'genepanel.disease_mode'},
#                                                                                        {'code': 'REQ_less_common',
#                                                                                         'match': ['less_common'],
#                                                                                         'op': '$in',
#                                                                                         'source': 'frequencies.commonness'},
#                                                                                        {'code': 'REQ_no_aa_change',
#                                                                                         'match': ['synonymous_variant'],
#                                                                                         'op': '$in',
#                                                                                         'source': 'transcript.consequences'},
#                                                                                        {'code': 'REQ_not_in_last_exon',
#                                                                                         'match': ['no'],
#                                                                                         'op': '$in',
#                                                                                         'source': 'transcript.in_last_exon'}]}},
#                                                  'reuse': True,
#                                                  'reuseCheckedId': 6},
#                             'allelereport': {'copiedFromId': 6,
#                                              'evaluation': {'comment': ''}},
#                             'analysis': {'comment': '',
#                                          'notrelevant': None,
#                                          'verification': 'verified'},
#                             'referenceassessments': [],
#                             'report': {'included': False},
#                             'workflow': {'reviewed': True}}},
#            'filterconfigId': 1,
#            'manuallyAddedAlleles': []},
#  'status': 'Done',
#  'user': {'abbrev_name': 'H. Ibsen',
#           'active': True,
#           'first_name': 'Henrik',
#           'full_name': 'Henrik Ibsen',
#           'id': 1,
#           'last_name': 'Ibsen',
#           'user_group_name': 'testgroup01',
#           'username': 'testuser1'},
#  'user_id': 1,
#  'user_state': {'allele': {'3': {'allele_id': 3,
#                                  'sections': {},
#                                  'showExcludedReferences': False},
#                            '4': {'allele_id': 4,
#                                  'sections': {},
#                                  'showExcludedReferences': False},
#                            '5': {'allele_id': 5,
#                                  'sections': {},
#                                  'showExcludedReferences': False},
#                            '6': {'allele_id': 6,
#                                  'sections': {},
#                                  'showExcludedReferences': False},
#                            '7': {'allele_id': 7,
#                                  'sections': {},
#                                  'showExcludedReferences': False},
#                            '8': {'allele_id': 8,
#                                  'sections': {},
#                                  'showExcludedReferences': False}}},
#  'workflow_status': 'Interpretation'}

# %%
response = session.get('{}/api/v1/analyses/2'.format(url))
pprint(json.loads(response.content.decode('utf-8')))
# Out:
# {'date_deposited': '2020-10-19T10:46:43.419040+00:00',
#  'date_requested': None,
#  'genepanel': {'name': 'HBOCUTV', 'version': 'v01'},
#  'id': 2,
#  'interpretations': [{'analysis_id': 2,
#                       'date_last_update': '2020-11-28T06:44:25.638124+00:00',
#                       'finalized': True,
#                       'genepanel_name': 'HBOCUTV',
#                       'genepanel_version': 'v01',
#                       'id': 2,
#                       'status': 'Done',
#                       'user': {'abbrev_name': 'H. Ibsen',
#                                'active': True,
#                                'first_name': 'Henrik',
#                                'full_name': 'Henrik Ibsen',
#                                'id': 1,
#                                'last_name': 'Ibsen',
#                                'user_group_name': 'testgroup01',
#                                'username': 'testuser1'},
#                       'user_id': 1,
#                       'workflow_status': 'Interpretation'}],
#  'name': 'brca_sample_1.HBOCUTV_v01',
#  'report': None,
#  'samples': [{'affected': True,
#               'date_deposited': '2020-10-19T10:46:43.434024+00:00',
#               'family_id': None,
#               'father_id': None,
#               'id': 2,
#               'identifier': 'brca_sample_1',
#               'mother_id': None,
#               'proband': True,
#               'sample_type': 'HTS',
#               'sex': None,
#               'sibling_id': None}],
#  'warnings': None}

# %% [markdown]
# ## Ella REST API Analysis Overview
#
# This is the sequence of events the REST API goes through when generating the Allele Interpretation Interface.

# %% [markdown]
# You can get this sequence by checking out the ella-web logs when you bring up an analysis page.
#
# ```
# #GET /api/v1/workflows/analyses/2/interpretations/2/alleles/
# GET /workflows/analyses/2/ HTTP/1.1"
#
# GET /api/v1/config/
# GET /api/v1/users/currentuser/
# GET /api/v1/workflows/analyses/2/stats/
# GET /api/v1/analyses/2/
# GET /api/v1/workflows/analyses/2/filterconfigs -
# GET /api/v1/workflows/analyses/2/filterconfigs/ -
# GET /api/v1/workflows/analyses/2/interpretations/  -
# GET /api/v1/workflows/analyses/2/interpretations/2/filteredalleles/?filterconfig_id=1 -
# GET /api/v1/workflows/analyses/2/genepanels/HBOCUTV/v01/?allele_ids=3%2C4%2C5%2C6%2C7%2C8  -
# GET /api/v1/workflows/analyses/2/interpretations/2/alleles/?allele_ids=3%2C4%2C5%2C6%2C7%2C8&current=true&filterconfig_id=1 HTTP/1.1" 200 -
# GET /api/v1/workflows/analyses/2/collisions/?allele_ids=3%2C4%2C5%2C6%2C7%2C8 HTTP/1.1" 200 -
# GET /api/v1/references/?q=%7B%22id%22%3A%5B%5D%7D HTTP/1.1" 200 -
# GET /api/v1/attachments/?q=%7B%22id%22%3A%5B%5D%7D HTTP/1.1" 200 -
# GET /api/v1/references/?q=%7B%22pubmed_id%22%3A%5B17453335%2C8589730%2C18607349%2C28324225%2C18092194%2C9245992%2C10070953%2C22430266%2C20927582%2C25525159%2C21356067%2C16760289%2C16847550%2C18844490%2C28492532%2C19471317%2C10923033%5D%7D HTTP/1.1" 200 -
# POST - http://localhost:5001/api/v1/acmg/alleles/ - {"allele_ids":["3","4","5","6","7","8"],"gp_name":"HBOCUTV","gp_version":"v01","referenceassessments":[]} - 4705 - 650ms
# "POST /api/v1/acmg/alleles/ HTTP/1.1" 200 -
# ```

# %%
#query_url = 'api/v1/workflows/analyses/2'
#response = session.get('{}/{}'.format(url, query_url))
#pprint(json.loads(response.content.decode('utf-8')))

# %%
query_url = 'api/v1/config/'
response = session.get('{}/{}'.format(url, query_url))
#pprint(json.loads(response.content.decode('utf-8')))

# %%
query_url = 'api/v1/workflows/analyses/2/stats/'
response = session.get('{}/{}'.format(url, query_url))
pprint(json.loads(response.content.decode('utf-8')))
# Out:
# {'allele_count': 6}

# %%
query_url = 'api/v1/analyses/2/'
response = session.get('{}/{}'.format(url, query_url))
pprint(json.loads(response.content.decode('utf-8')))
# Out:
# {'date_deposited': '2020-10-19T10:46:43.419040+00:00',
#  'date_requested': None,
#  'genepanel': {'name': 'HBOCUTV', 'version': 'v01'},
#  'id': 2,
#  'interpretations': [{'analysis_id': 2,
#                       'date_last_update': '2020-11-28T06:44:25.638124+00:00',
#                       'finalized': True,
#                       'genepanel_name': 'HBOCUTV',
#                       'genepanel_version': 'v01',
#                       'id': 2,
#                       'status': 'Done',
#                       'user': {'abbrev_name': 'H. Ibsen',
#                                'active': True,
#                                'first_name': 'Henrik',
#                                'full_name': 'Henrik Ibsen',
#                                'id': 1,
#                                'last_name': 'Ibsen',
#                                'user_group_name': 'testgroup01',
#                                'username': 'testuser1'},
#                       'user_id': 1,
#                       'workflow_status': 'Interpretation'}],
#  'name': 'brca_sample_1.HBOCUTV_v01',
#  'report': None,
#  'samples': [{'affected': True,
#               'date_deposited': '2020-10-19T10:46:43.434024+00:00',
#               'family_id': None,
#               'father_id': None,
#               'id': 2,
#               'identifier': 'brca_sample_1',
#               'mother_id': None,
#               'proband': True,
#               'sample_type': 'HTS',
#               'sex': None,
#               'sibling_id': None}],
#  'warnings': None}

# %%
query_url = 'api/v1/workflows/analyses/2/filterconfigs/'
response = session.get('{}/{}'.format(url, query_url))
#pprint(json.loads(response.content.decode('utf-8')))

# %%
## Get some filtered alleles

query_url = 'api/v1/workflows/analyses/2/interpretations/2/filteredalleles/'
payload = {'filterconfig': 1}
response = session.get('{}/{}'.format(url, query_url), params=payload)
response = json.loads(response.content.decode('utf-8'))
pprint(response)
allele_ids = response['allele_ids']
allele_ids
# Out:
# {'allele_ids': [3, 4, 5, 6, 7, 8],
#  'excluded_allele_ids': {'classification': [],
#                          'consequence': [],
#                          'frequency': [],
#                          'gene': [],
#                          'inheritancemodel': [],
#                          'ppy': [],
#                          'quality': [],
#                          'region': [],
#                          'segregation': []}}
# [3, 4, 5, 6, 7, 8]

# %%
# /api/v1/workflows/analyses/2/genepanels/HBOCUTV/v01/?allele_ids=3%2C4%2C5%2C6%2C7%2C8 

# TODO Get the Genepanel from the analysis def
query_url = 'api/v1/workflows/analyses/2/genepanels/HBOCUTV/v01/'
payload = {'allele_ids': allele_ids}
response = session.get('{}/{}'.format(url, query_url), params=payload)
response = json.loads(response.content.decode('utf-8'))
pprint(response)
# Out:
# {'geneassessments': [],
#  'name': 'HBOCUTV',
#  'phenotypes': [{'description': '{Breast cancer, male, susceptibility to}',
#                  'gene': {'ensembl_gene_id': 'ENSG00000139618',
#                           'hgnc_id': 1101,
#                           'hgnc_symbol': 'BRCA2',
#                           'omim_entry_id': 600185},
#                  'id': 6,
#                  'inheritance': 'AD',
#                  'omim_id': 114480},
#                 {'description': '{Breast-ovarian cancer, familial, 2}',
#                  'gene': {'ensembl_gene_id': 'ENSG00000139618',
#                           'hgnc_id': 1101,
#                           'hgnc_symbol': 'BRCA2',
#                           'omim_entry_id': 600185},
#                  'id': 2,
#                  'inheritance': 'AD',
#                  'omim_id': 612555},
#                 {'description': 'Fanconi anemia, complementation group D1',
#                  'gene': {'ensembl_gene_id': 'ENSG00000139618',
#                           'hgnc_id': 1101,
#                           'hgnc_symbol': 'BRCA2',
#                           'omim_entry_id': 600185},
#                  'id': 4,
#                  'inheritance': 'AR',
#                  'omim_id': 605724},
#                 {'description': '{Glioblastoma 3}',
#                  'gene': {'ensembl_gene_id': 'ENSG00000139618',
#                           'hgnc_id': 1101,
#                           'hgnc_symbol': 'BRCA2',
#                           'omim_entry_id': 600185},
#                  'id': 7,
#                  'inheritance': 'AR',
#                  'omim_id': 613029},
#                 {'description': '{Medulloblastoma}',
#                  'gene': {'ensembl_gene_id': 'ENSG00000139618',
#                           'hgnc_id': 1101,
#                           'hgnc_symbol': 'BRCA2',
#                           'omim_entry_id': 600185},
#                  'id': 8,
#                  'inheritance': 'AD;AR',
#                  'omim_id': 155255},
#                 {'description': '{Pancreatic cancer 2}',
#                  'gene': {'ensembl_gene_id': 'ENSG00000139618',
#                           'hgnc_id': 1101,
#                           'hgnc_symbol': 'BRCA2',
#                           'omim_entry_id': 600185},
#                  'id': 9,
#                  'inheritance': '',
#                  'omim_id': 613347},
#                 {'description': '{Prostate cancer}',
#                  'gene': {'ensembl_gene_id': 'ENSG00000139618',
#                           'hgnc_id': 1101,
#                           'hgnc_symbol': 'BRCA2',
#                           'omim_entry_id': 600185},
#                  'id': 10,
#                  'inheritance': 'AD',
#                  'omim_id': 176807},
#                 {'description': 'Wilms tumor',
#                  'gene': {'ensembl_gene_id': 'ENSG00000139618',
#                           'hgnc_id': 1101,
#                           'hgnc_symbol': 'BRCA2',
#                           'omim_entry_id': 600185},
#                  'id': 5,
#                  'inheritance': 'AD;SMu',
#                  'omim_id': 194070}],
#  'transcripts': [{'cds_end': 32972907,
#                   'cds_start': 32890597,
#                   'chromosome': '13',
#                   'corresponding_ensembl': 'ENST00000544455',
#                   'corresponding_lrg': None,
#                   'corresponding_refseq': None,
#                   'exon_ends': [32889804,
#                                 32890664,
#                                 32893462,
#                                 32899321,
#                                 32900287,
#                                 32900419,
#                                 32900750,
#                                 32903629,
#                                 32905167,
#                                 32907524,
#                                 32915333,
#                                 32918790,
#                                 32921033,
#                                 32929425,
#                                 32930746,
#                                 32932066,
#                                 32936830,
#                                 32937670,
#                                 32944694,
#                                 32945237,
#                                 32950928,
#                                 32953652,
#                                 32954050,
#                                 32954282,
#                                 32969070,
#                                 32971181,
#                                 32973809],
#                   'exon_starts': [32889616,
#                                   32890558,
#                                   32893213,
#                                   32899212,
#                                   32900237,
#                                   32900378,
#                                   32900635,
#                                   32903579,
#                                   32905055,
#                                   32906408,
#                                   32910401,
#                                   32918694,
#                                   32920963,
#                                   32928997,
#                                   32930564,
#                                   32931878,
#                                   32936659,
#                                   32937315,
#                                   32944538,
#                                   32945092,
#                                   32950806,
#                                   32953453,
#                                   32953886,
#                                   32954143,
#                                   32968825,
#                                   32971034,
#                                   32972298],
#                   'gene': {'ensembl_gene_id': 'ENSG00000139618',
#                            'hgnc_id': 1101,
#                            'hgnc_symbol': 'BRCA2',
#                            'omim_entry_id': 600185},
#                   'genome_reference': 'GRCh37',
#                   'strand': '+',
#                   'transcript_name': 'NM_000059.3',
#                   'tx_end': 32973809,
#                   'tx_start': 32889616}],
#  'version': 'v01'}

# %%
# /api/v1/workflows/analyses/2/interpretations/2/alleles/
# ?allele_ids=3%2C4%2C5%2C6%2C7%2C8&current=true&filterconfig_id=1

query_url = 'api/v1/workflows/analyses/2/interpretations/2/alleles/'
# Allele Ids needs to be a string with comma separated values, not a list!
payload = {'allele_ids': ','.join([str(x) for x in allele_ids]), 
           'current': True, 
           'filterconfig_id': 1
          }
response = session.get('{}/{}'.format(url, query_url), params=payload)

print(response.url)
response = json.loads(response.content.decode('utf-8'))
pprint(len(response))
pprint(response)
# Out:
# http://ella-web:5000/api/v1/workflows/analyses/2/interpretations/2/alleles/?allele_ids=3%2C4%2C5%2C6%2C7%2C8&current=True&filterconfig_id=1
# 6
# [{'allele_assessment': {'allele_id': 3,
#                         'analysis_id': 2,
#                         'annotation_id': 3,
#                         'attachment_ids': [],
#                         'classification': '4',
#                         'custom_annotation_id': None,
#                         'date_created': '2020-10-19T10:49:44.630277+00:00',
#                         'date_superceeded': None,
#                         'evaluation': {'acmg': {'included': [{'code': 'PVS1',
#                                                               'comment': '',
#                                                               'match': None,
#                                                               'op': None,
#                                                               'source': 'suggested',
#                                                               'uuid': '5104d287-683d-4391-a75b-5694c65f2b88'},
#                                                              {'code': 'PPxPM2',
#                                                               'comment': '',
#                                                               'match': None,
#                                                               'op': None,
#                                                               'source': 'suggested',
#                                                               'uuid': 'b44315f8-2db9-4605-b824-acf51e50ac31'}],
#                                                 'suggested': [{'code': 'REQ_GP_last_exon_not_important',
#                                                                'match': ['LENI'],
#                                                                'op': '$in',
#                                                                'source': 'genepanel.last_exon_important'},
#                                                               {'code': 'REQ_GP_LOF_missense',
#                                                                'match': ['ANY'],
#                                                                'op': '$in',
#                                                                'source': 'genepanel.disease_mode'},
#                                                               {'code': 'REQ_not_in_last_exon',
#                                                                'match': ['no'],
#                                                                'op': '$in',
#                                                                'source': 'transcript.in_last_exon'},
#                                                               {'code': 'REQ_null_variant',
#                                                                'match': ['stop_gained'],
#                                                                'op': '$in',
#                                                                'source': 'transcript.consequences'},
#                                                               {'code': 'REQ_no_freq',
#                                                                'match': ['null_freq'],
#                                                                'op': '$in',
#                                                                'source': 'frequencies.commonness'},
#                                                               {'code': 'PVS1',
#                                                                'match': None,
#                                                                'op': None,
#                                                                'source': None},
#                                                               {'code': 'PPxPM2',
#                                                                'match': None,
#                                                                'op': None,
#                                                                'source': None}],
#                                                 'suggested_classification': 4},
#                                        'classification': {'comment': ''},
#                                        'external': {'comment': ''},
#                                        'frequency': {'comment': ''},
#                                        'prediction': {'comment': ''},
#                                        'reference': {'comment': ''}},
#                         'genepanel_name': 'HBOCUTV',
#                         'genepanel_version': 'v01',
#                         'id': 1,
#                         'previous_assessment_id': None,
#                         'seconds_since_update': 3448206.50482,
#                         'user': {'abbrev_name': 'H. Ibsen',
#                                  'active': True,
#                                  'first_name': 'Henrik',
#                                  'full_name': 'Henrik Ibsen',
#                                  'id': 1,
#                                  'last_name': 'Ibsen',
#                                  'user_group_name': 'testgroup01',
#                                  'username': 'testuser1'},
#                         'user_id': 1,
#                         'usergroup': {'id': 1, 'name': 'testgroup01'},
#                         'usergroup_id': 1},
#   'allele_report': {'allele_id': 3,
#                     'analysis_id': 2,
#                     'date_created': '2020-10-19T10:49:44.640931+00:00',
#                     'date_superceeded': None,
#                     'evaluation': {'comment': ''},
#                     'id': 1,
#                     'previous_report_id': None,
#                     'seconds_since_update': 3448206.53819,
#                     'user': {'abbrev_name': 'H. Ibsen',
#                              'active': True,
#                              'first_name': 'Henrik',
#                              'full_name': 'Henrik Ibsen',
#                              'id': 1,
#                              'last_name': 'Ibsen',
#                              'user_group_name': 'testgroup01',
#                              'username': 'testuser1'},
#                     'user_id': 1,
#                     'usergroup': {'id': 1, 'name': 'testgroup01'},
#                     'usergroup_id': 1},
#   'annotation': {'annotation_id': 3,
#                  'external': {'CLINVAR': {'items': [{'clinical_significance_descr': 'Pathogenic',
#                                                      'last_evaluated': '01/11/2017',
#                                                      'rcv': 'SCV000296805',
#                                                      'submitter': 'GeneKor MSA',
#                                                      'traitnames': '',
#                                                      'variant_id': ''},
#                                                     {'clinical_significance_descr': 'Pathogenic',
#                                                      'last_evaluated': '18/10/2016',
#                                                      'rcv': 'SCV000323955',
#                                                      'submitter': 'ENIGMA',
#                                                      'traitnames': '',
#                                                      'variant_id': ''},
#                                                     {'clinical_significance_descr': 'Pathogenic',
#                                                      'last_evaluated': '18/10/2016',
#                                                      'rcv': 'RCV000257718',
#                                                      'submitter': '',
#                                                      'traitnames': 'Breast-ovarian '
#                                                                    'cancer, '
#                                                                    'familial 2',
#                                                      'variant_id': '51063'},
#                                                     {'clinical_significance_descr': 'Pathogenic',
#                                                      'last_evaluated': '01/11/2017',
#                                                      'rcv': 'RCV000239090',
#                                                      'submitter': '',
#                                                      'traitnames': 'not '
#                                                                    'provided',
#                                                      'variant_id': '51063'},
#                                                     {'clinical_significance_descr': 'Pathogenic',
#                                                      'last_evaluated': '02/10/2015',
#                                                      'rcv': 'SCV000326495',
#                                                      'submitter': 'CIMBA',
#                                                      'traitnames': '',
#                                                      'variant_id': ''}],
#                                           'variant_description': 'reviewed by '
#                                                                  'expert panel',
#                                           'variant_id': 51063},
#                               'HGMD': {'acc_num': 'CM082514',
#                                        'codon': 4,
#                                        'disease': 'Breast and/or ovarian '
#                                                   'cancer',
#                                        'tag': 'DM'}},
#                  'filtered_transcripts': ['NM_000059.3'],
#                  'frequencies': {},
#                  'prediction': {},
#                  'references': [{'pubmed_id': 17453335,
#                                  'source_info': {'HGMD': 'Primary literature '
#                                                          'report. No '
#                                                          'comments.'},
#                                  'sources': ['HGMD']}],
#                  'schema_version': 1,
#                  'transcripts': [{'HGVSc': 'c.10G>T',
#                                   'HGVSc_short': 'c.10G>T',
#                                   'HGVSp': 'p.Gly4Ter',
#                                   'amino_acids': 'G/*',
#                                   'coding_region_distance': 0,
#                                   'codons': 'Gga/Tga',
#                                   'consequences': ['stop_gained'],
#                                   'dbsnp': ['rs397507571'],
#                                   'exon': '2/27',
#                                   'exon_distance': 0,
#                                   'hgnc_id': 1101,
#                                   'in_last_exon': 'no',
#                                   'is_canonical': True,
#                                   'protein': 'NP_000050.2',
#                                   'strand': 1,
#                                   'symbol': 'BRCA2',
#                                   'transcript': 'NM_000059.3'},
#                                  {'consequences': ['upstream_gene_variant'],
#                                   'dbsnp': ['rs397507571'],
#                                   'hgnc_id': 37116,
#                                   'in_last_exon': 'no',
#                                   'is_canonical': True,
#                                   'strand': -1,
#                                   'symbol': 'ZAR1L',
#                                   'transcript': 'NM_001136571.1'}],
#                  'worst_consequence': ['NM_000059.3']},
#   'change_from': 'G',
#   'change_to': 'T',
#   'change_type': 'SNP',
#   'chromosome': '13',
#   'genome_reference': 'GRCh37',
#   'id': 3,
#   'open_end_position': 32890607,
#   'samples': [{'affected': True,
#                'date_deposited': '2020-10-19T10:46:43.434024+00:00',
#                'family_id': None,
#                'father_id': None,
#                'genotype': {'allele_depth': {'REF (G)': 107, 'T': 80},
#                             'allele_ratio': 0.42780748663101603,
#                             'filter_status': 'PASS',
#                             'formatted': 'G/T',
#                             'genotype_quality': 99,
#                             'id': 3,
#                             'multiallelic': False,
#                             'needs_verification': False,
#                             'needs_verification_checks': {'allele_ratio': True,
#                                                           'dp': True,
#                                                           'hts': True,
#                                                           'pass': True,
#                                                           'snp': True},
#                             'sequencing_depth': 187,
#                             'type': 'Heterozygous',
#                             'variant_quality': 5000},
#                'id': 2,
#                'identifier': 'brca_sample_1',
#                'mother_id': None,
#                'proband': True,
#                'sample_type': 'HTS',
#                'sex': None,
#                'sibling_id': None}],
#   'start_position': 32890606,
#   'tags': ['has_references'],
#   'vcf_alt': 'T',
#   'vcf_pos': 32890607,
#   'vcf_ref': 'G'},
#  {'allele_assessment': {'allele_id': 4,
#                         'analysis_id': 2,
#                         'annotation_id': 4,
#                         'attachment_ids': [],
#                         'classification': '4',
#                         'custom_annotation_id': None,
#                         'date_created': '2020-10-19T10:50:00.770452+00:00',
#                         'date_superceeded': None,
#                         'evaluation': {'acmg': {'included': [{'code': 'PVS1',
#                                                               'comment': '',
#                                                               'match': None,
#                                                               'op': None,
#                                                               'source': 'suggested',
#                                                               'uuid': '9f3d29e2-aa9c-477a-9203-ad2419b56212'},
#                                                              {'code': 'PPxPM2',
#                                                               'comment': '',
#                                                               'match': None,
#                                                               'op': None,
#                                                               'source': 'suggested',
#                                                               'uuid': 'a3d24926-c0c4-407f-af82-8d6f5b4bb6f4'}],
#                                                 'suggested': [{'code': 'REQ_GP_last_exon_not_important',
#                                                                'match': ['LENI'],
#                                                                'op': '$in',
#                                                                'source': 'genepanel.last_exon_important'},
#                                                               {'code': 'REQ_GP_LOF_missense',
#                                                                'match': ['ANY'],
#                                                                'op': '$in',
#                                                                'source': 'genepanel.disease_mode'},
#                                                               {'code': 'REQ_not_in_last_exon',
#                                                                'match': ['no'],
#                                                                'op': '$in',
#                                                                'source': 'transcript.in_last_exon'},
#                                                               {'code': 'REQ_null_variant',
#                                                                'match': ['frameshift_variant'],
#                                                                'op': '$in',
#                                                                'source': 'transcript.consequences'},
#                                                               {'code': 'REQ_no_freq',
#                                                                'match': ['null_freq'],
#                                                                'op': '$in',
#                                                                'source': 'frequencies.commonness'},
#                                                               {'code': 'PVS1',
#                                                                'match': None,
#                                                                'op': None,
#                                                                'source': None},
#                                                               {'code': 'PPxPM2',
#                                                                'match': None,
#                                                                'op': None,
#                                                                'source': None}],
#                                                 'suggested_classification': 4},
#                                        'classification': {'comment': ''},
#                                        'external': {'comment': ''},
#                                        'frequency': {'comment': ''},
#                                        'prediction': {'comment': ''},
#                                        'reference': {'comment': ''}},
#                         'genepanel_name': 'HBOCUTV',
#                         'genepanel_version': 'v01',
#                         'id': 2,
#                         'previous_assessment_id': None,
#                         'seconds_since_update': 3448190.371559,
#                         'user': {'abbrev_name': 'H. Ibsen',
#                                  'active': True,
#                                  'first_name': 'Henrik',
#                                  'full_name': 'Henrik Ibsen',
#                                  'id': 1,
#                                  'last_name': 'Ibsen',
#                                  'user_group_name': 'testgroup01',
#                                  'username': 'testuser1'},
#                         'user_id': 1,
#                         'usergroup': {'id': 1, 'name': 'testgroup01'},
#                         'usergroup_id': 1},
#   'allele_report': {'allele_id': 4,
#                     'analysis_id': 2,
#                     'date_created': '2020-10-19T10:50:00.778677+00:00',
#                     'date_superceeded': None,
#                     'evaluation': {'comment': ''},
#                     'id': 2,
#                     'previous_report_id': None,
#                     'seconds_since_update': 3448190.402037,
#                     'user': {'abbrev_name': 'H. Ibsen',
#                              'active': True,
#                              'first_name': 'Henrik',
#                              'full_name': 'Henrik Ibsen',
#                              'id': 1,
#                              'last_name': 'Ibsen',
#                              'user_group_name': 'testgroup01',
#                              'username': 'testuser1'},
#                     'user_id': 1,
#                     'usergroup': {'id': 1, 'name': 'testgroup01'},
#                     'usergroup_id': 1},
#   'annotation': {'annotation_id': 4,
#                  'external': {'CLINVAR': {'items': [{'clinical_significance_descr': 'Pathogenic',
#                                                      'last_evaluated': '12/12/2016',
#                                                      'rcv': 'RCV000131871',
#                                                      'submitter': '',
#                                                      'traitnames': 'Hereditary '
#                                                                    'cancer-predisposing '
#                                                                    'syndrome',
#                                                      'variant_id': '51814'},
#                                                     {'clinical_significance_descr': 'Pathogenic',
#                                                      'last_evaluated': '21/01/2016',
#                                                      'rcv': 'SCV000279262',
#                                                      'submitter': 'GeneDx',
#                                                      'traitnames': 'Not '
#                                                                    'Provided',
#                                                      'variant_id': ''},
#                                                     {'clinical_significance_descr': 'Pathogenic',
#                                                      'last_evaluated': '22/04/2016',
#                                                      'rcv': 'SCV000282398',
#                                                      'submitter': 'ENIGMA',
#                                                      'traitnames': '',
#                                                      'variant_id': ''},
#                                                     {'clinical_significance_descr': 'Pathogenic',
#                                                      'last_evaluated': '22/04/2016',
#                                                      'rcv': 'RCV000113063',
#                                                      'submitter': '',
#                                                      'traitnames': 'Breast-ovarian '
#                                                                    'cancer, '
#                                                                    'familial 2',
#                                                      'variant_id': '51814'},
#                                                     {'clinical_significance_descr': 'Pathogenic',
#                                                      'last_evaluated': '06/01/2016',
#                                                      'rcv': 'SCV000694829',
#                                                      'submitter': 'Integrated '
#                                                                   'Genetics/Laboratory '
#                                                                   'Corporation '
#                                                                   'of America',
#                                                      'traitnames': '',
#                                                      'variant_id': ''},
#                                                     {'clinical_significance_descr': 'Pathogenic',
#                                                      'last_evaluated': '02/10/2015',
#                                                      'rcv': 'SCV000327129',
#                                                      'submitter': 'CIMBA',
#                                                      'traitnames': '',
#                                                      'variant_id': ''},
#                                                     {'clinical_significance_descr': 'Pathogenic',
#                                                      'last_evaluated': '23/09/2016',
#                                                      'rcv': 'SCV000186926',
#                                                      'submitter': 'Ambry '
#                                                                   'Genetics',
#                                                      'traitnames': 'Hereditary '
#                                                                    'cancer-predisposing '
#                                                                    'syndrome',
#                                                      'variant_id': ''},
#                                                     {'clinical_significance_descr': 'Pathogenic',
#                                                      'last_evaluated': '29/05/2002',
#                                                      'rcv': 'SCV000146071',
#                                                      'submitter': 'BIC (BRCA2)',
#                                                      'traitnames': 'Breast-ovarian '
#                                                                    'cancer, '
#                                                                    'familial 2',
#                                                      'variant_id': ''},
#                                                     {'clinical_significance_descr': 'Pathogenic',
#                                                      'last_evaluated': '21/01/2016',
#                                                      'rcv': 'RCV000219019',
#                                                      'submitter': '',
#                                                      'traitnames': 'not '
#                                                                    'provided',
#                                                      'variant_id': '51814'},
#                                                     {'clinical_significance_descr': 'Pathogenic',
#                                                      'last_evaluated': '12/12/2016',
#                                                      'rcv': 'SCV000683670',
#                                                      'submitter': 'Color '
#                                                                   'Genomics, '
#                                                                   'Inc.',
#                                                      'traitnames': '',
#                                                      'variant_id': ''},
#                                                     {'clinical_significance_descr': 'Pathogenic',
#                                                      'last_evaluated': '17/02/2015',
#                                                      'rcv': 'SCV000591655',
#                                                      'submitter': 'Department '
#                                                                   'of '
#                                                                   'Pathology '
#                                                                   'and '
#                                                                   'Laboratory '
#                                                                   'Medicine,Sinai '
#                                                                   'Health '
#                                                                   'System',
#                                                      'traitnames': '',
#                                                      'variant_id': ''},
#                                                     {'clinical_significance_descr': 'Pathogenic',
#                                                      'last_evaluated': '31/01/2014',
#                                                      'rcv': 'SCV000587530',
#                                                      'submitter': 'Research '
#                                                                   'Molecular '
#                                                                   'Genetics '
#                                                                   "Laboratory,Women's "
#                                                                   'College '
#                                                                   'Hospital, '
#                                                                   'University '
#                                                                   'of Toronto',
#                                                      'traitnames': '',
#                                                      'variant_id': ''},
#                                                     {'clinical_significance_descr': 'Pathogenic',
#                                                      'last_evaluated': '06/01/2016',
#                                                      'rcv': 'RCV000496563',
#                                                      'submitter': '',
#                                                      'traitnames': 'Hereditary '
#                                                                    'breast and '
#                                                                    'ovarian '
#                                                                    'cancer '
#                                                                    'syndrome',
#                                                      'variant_id': '51814'},
#                                                     {'clinical_significance_descr': 'Pathogenic',
#                                                      'last_evaluated': '01/07/2016',
#                                                      'rcv': 'RCV000044604',
#                                                      'submitter': '',
#                                                      'traitnames': 'Familial '
#                                                                    'cancer of '
#                                                                    'breast',
#                                                      'variant_id': '51814'},
#                                                     {'clinical_significance_descr': 'Pathogenic',
#                                                      'last_evaluated': '01/07/2016',
#                                                      'rcv': 'SCV000296839',
#                                                      'submitter': 'GeneKor MSA',
#                                                      'traitnames': '',
#                                                      'variant_id': ''}],
#                                           'variant_description': 'reviewed by '
#                                                                  'expert panel',
#                                           'variant_id': 51814},
#                               'HGMD': {'acc_num': 'CD961847',
#                                        'codon': 16,
#                                        'disease': 'Breast cancer',
#                                        'tag': 'DM'}},
#                  'filtered_transcripts': ['NM_000059.3'],
#                  'frequencies': {},
#                  'prediction': {},
#                  'references': [{'pubmed_id': 8589730,
#                                  'source_info': {'HGMD': 'Primary literature '
#                                                          'report. aka '
#                                                          '279delAC.'},
#                                  'sources': ['HGMD', 'CLINVAR']},
#                                 {'pubmed_id': 18607349,
#                                  'source_info': {'HGMD': 'Functional '
#                                                          'characterisation. No '
#                                                          'comments.'},
#                                  'sources': ['HGMD', 'CLINVAR']},
#                                 {'pubmed_id': 28324225,
#                                  'source_info': {'HGMD': 'Additional '
#                                                          'phenotype. Breast '
#                                                          'and/or ovarian '
#                                                          'cancer.'},
#                                  'sources': ['HGMD']},
#                                 {'pubmed_id': 18092194,
#                                  'source_info': {},
#                                  'sources': ['CLINVAR']},
#                                 {'pubmed_id': 9245992,
#                                  'source_info': {},
#                                  'sources': ['CLINVAR']},
#                                 {'pubmed_id': 10070953,
#                                  'source_info': {},
#                                  'sources': ['CLINVAR']},
#                                 {'pubmed_id': 22430266,
#                                  'source_info': {},
#                                  'sources': ['CLINVAR']},
#                                 {'pubmed_id': 20927582,
#                                  'source_info': {},
#                                  'sources': ['CLINVAR']}],
#                  'schema_version': 1,
#                  'transcripts': [{'HGVSc': 'c.51_52delAC',
#                                   'HGVSc_short': 'c.51_52delAC',
#                                   'HGVSp': 'p.Arg18LeufsTer12',
#                                   'amino_acids': 'T/X',
#                                   'coding_region_distance': 0,
#                                   'codons': 'ACa/a',
#                                   'consequences': ['frameshift_variant'],
#                                   'exon': '2/27',
#                                   'exon_distance': 0,
#                                   'hgnc_id': 1101,
#                                   'in_last_exon': 'no',
#                                   'is_canonical': True,
#                                   'protein': 'NP_000050.2',
#                                   'strand': 1,
#                                   'symbol': 'BRCA2',
#                                   'transcript': 'NM_000059.3'},
#                                  {'consequences': ['upstream_gene_variant'],
#                                   'hgnc_id': 37116,
#                                   'in_last_exon': 'no',
#                                   'is_canonical': True,
#                                   'strand': -1,
#                                   'symbol': 'ZAR1L',
#                                   'transcript': 'NM_001136571.1'}],
#                  'worst_consequence': ['NM_000059.3']},
#   'change_from': 'AC',
#   'change_to': '',
#   'change_type': 'del',
#   'chromosome': '13',
#   'genome_reference': 'GRCh37',
#   'id': 4,
#   'open_end_position': 32890647,
#   'samples': [{'affected': True,
#                'date_deposited': '2020-10-19T10:46:43.434024+00:00',
#                'family_id': None,
#                'father_id': None,
#                'genotype': {'allele_depth': {'G': 80, 'REF (GAC)': 107},
#                             'allele_ratio': 0.42780748663101603,
#                             'filter_status': 'PASS',
#                             'formatted': 'AC/-',
#                             'genotype_quality': 99,
#                             'id': 4,
#                             'multiallelic': False,
#                             'needs_verification': True,
#                             'needs_verification_checks': {'allele_ratio': True,
#                                                           'dp': True,
#                                                           'hts': True,
#                                                           'pass': True,
#                                                           'snp': False},
#                             'sequencing_depth': 187,
#                             'type': 'Heterozygous',
#                             'variant_quality': 5000},
#                'id': 2,
#                'identifier': 'brca_sample_1',
#                'mother_id': None,
#                'proband': True,
#                'sample_type': 'HTS',
#                'sex': None,
#                'sibling_id': None}],
#   'start_position': 32890645,
#   'tags': ['has_references'],
#   'vcf_alt': 'G',
#   'vcf_pos': 32890645,
#   'vcf_ref': 'GAC'},
#  {'allele_assessment': {'allele_id': 5,
#                         'analysis_id': 2,
#                         'annotation_id': 5,
#                         'attachment_ids': [],
#                         'classification': '4',
#                         'custom_annotation_id': None,
#                         'date_created': '2020-10-19T10:50:14.357702+00:00',
#                         'date_superceeded': None,
#                         'evaluation': {'acmg': {'included': [{'code': 'PVS1',
#                                                               'comment': '',
#                                                               'match': None,
#                                                               'op': None,
#                                                               'source': 'suggested',
#                                                               'uuid': 'a6640f97-6c04-4d6c-80d8-d7316097c2b3'},
#                                                              {'code': 'PPxPM2',
#                                                               'comment': '',
#                                                               'match': None,
#                                                               'op': None,
#                                                               'source': 'suggested',
#                                                               'uuid': '78328515-d040-45c6-8e23-21fee75294c5'}],
#                                                 'suggested': [{'code': 'REQ_GP_last_exon_not_important',
#                                                                'match': ['LENI'],
#                                                                'op': '$in',
#                                                                'source': 'genepanel.last_exon_important'},
#                                                               {'code': 'REQ_GP_LOF_missense',
#                                                                'match': ['ANY'],
#                                                                'op': '$in',
#                                                                'source': 'genepanel.disease_mode'},
#                                                               {'code': 'REQ_not_in_last_exon',
#                                                                'match': ['no'],
#                                                                'op': '$in',
#                                                                'source': 'transcript.in_last_exon'},
#                                                               {'code': 'REQ_null_variant',
#                                                                'match': ['splice_donor_variant'],
#                                                                'op': '$in',
#                                                                'source': 'transcript.consequences'},
#                                                               {'code': 'REQ_no_freq',
#                                                                'match': ['null_freq'],
#                                                                'op': '$in',
#                                                                'source': 'frequencies.commonness'},
#                                                               {'code': 'PVS1',
#                                                                'match': None,
#                                                                'op': None,
#                                                                'source': None},
#                                                               {'code': 'PPxPM2',
#                                                                'match': None,
#                                                                'op': None,
#                                                                'source': None}],
#                                                 'suggested_classification': 4},
#                                        'classification': {'comment': ''},
#                                        'external': {'comment': ''},
#                                        'frequency': {'comment': ''},
#                                        'prediction': {'comment': ''},
#                                        'reference': {'comment': ''}},
#                         'genepanel_name': 'HBOCUTV',
#                         'genepanel_version': 'v01',
#                         'id': 3,
#                         'previous_assessment_id': None,
#                         'seconds_since_update': 3448176.792547,
#                         'user': {'abbrev_name': 'H. Ibsen',
#                                  'active': True,
#                                  'first_name': 'Henrik',
#                                  'full_name': 'Henrik Ibsen',
#                                  'id': 1,
#                                  'last_name': 'Ibsen',
#                                  'user_group_name': 'testgroup01',
#                                  'username': 'testuser1'},
#                         'user_id': 1,
#                         'usergroup': {'id': 1, 'name': 'testgroup01'},
#                         'usergroup_id': 1},
#   'allele_report': {'allele_id': 5,
#                     'analysis_id': 2,
#                     'date_created': '2020-10-19T10:50:14.366927+00:00',
#                     'date_superceeded': None,
#                     'evaluation': {'comment': ''},
#                     'id': 3,
#                     'previous_report_id': None,
#                     'seconds_since_update': 3448176.81548,
#                     'user': {'abbrev_name': 'H. Ibsen',
#                              'active': True,
#                              'first_name': 'Henrik',
#                              'full_name': 'Henrik Ibsen',
#                              'id': 1,
#                              'last_name': 'Ibsen',
#                              'user_group_name': 'testgroup01',
#                              'username': 'testuser1'},
#                     'user_id': 1,
#                     'usergroup': {'id': 1, 'name': 'testgroup01'},
#                     'usergroup_id': 1},
#   'annotation': {'annotation_id': 5,
#                  'external': {'CLINVAR': {'items': [{'clinical_significance_descr': 'Pathogenic',
#                                                      'last_evaluated': '24/02/2003',
#                                                      'rcv': 'RCV000113080',
#                                                      'submitter': '',
#                                                      'traitnames': 'Breast-ovarian '
#                                                                    'cancer, '
#                                                                    'familial 2',
#                                                      'variant_id': '52162'},
#                                                     {'clinical_significance_descr': 'Pathogenic',
#                                                      'last_evaluated': '24/02/2003',
#                                                      'rcv': 'SCV000146095',
#                                                      'submitter': 'BIC (BRCA2)',
#                                                      'traitnames': 'Breast-ovarian '
#                                                                    'cancer, '
#                                                                    'familial 2',
#                                                      'variant_id': ''}],
#                                           'variant_description': 'no assertion '
#                                                                  'criteria '
#                                                                  'provided',
#                                           'variant_id': 52162},
#                               'HGMD': {'acc_num': 'CS087186',
#                                        'disease': 'Breast cancer',
#                                        'tag': 'DM'}},
#                  'filtered_transcripts': ['NM_000059.3'],
#                  'frequencies': {},
#                  'prediction': {},
#                  'references': [{'pubmed_id': 18092194,
#                                  'source_info': {'HGMD': 'Primary literature '
#                                                          'report. Descr. in '
#                                                          'Suppl. Table 1 '
#                                                          '(online).'},
#                                  'sources': ['HGMD']},
#                                 {'pubmed_id': 25525159,
#                                  'source_info': {'HGMD': 'Additional report. '
#                                                          'predicted to induce '
#                                                          'a large splicing '
#                                                          'change - Table S4.'},
#                                  'sources': ['HGMD']}],
#                  'schema_version': 1,
#                  'transcripts': [{'HGVSc': 'c.67+2T>A',
#                                   'HGVSc_short': 'c.67+2T>A',
#                                   'coding_region_distance': None,
#                                   'consequences': ['splice_donor_variant'],
#                                   'dbsnp': ['rs81002885'],
#                                   'exon_distance': 2,
#                                   'hgnc_id': 1101,
#                                   'in_last_exon': 'no',
#                                   'intron': '2/26',
#                                   'is_canonical': True,
#                                   'strand': 1,
#                                   'symbol': 'BRCA2',
#                                   'transcript': 'NM_000059.3'},
#                                  {'consequences': ['upstream_gene_variant'],
#                                   'dbsnp': ['rs81002885'],
#                                   'hgnc_id': 37116,
#                                   'in_last_exon': 'no',
#                                   'is_canonical': True,
#                                   'strand': -1,
#                                   'symbol': 'ZAR1L',
#                                   'transcript': 'NM_001136571.1'}],
#                  'worst_consequence': ['NM_000059.3']},
#   'change_from': 'T',
#   'change_to': 'A',
#   'change_type': 'SNP',
#   'chromosome': '13',
#   'genome_reference': 'GRCh37',
#   'id': 5,
#   'open_end_position': 32890666,
#   'samples': [{'affected': True,
#                'date_deposited': '2020-10-19T10:46:43.434024+00:00',
#                'family_id': None,
#                'father_id': None,
#                'genotype': {'allele_depth': {'A': 80, 'REF (T)': 107},
#                             'allele_ratio': 0.42780748663101603,
#                             'filter_status': 'PASS',
#                             'formatted': 'T/A',
#                             'genotype_quality': 99,
#                             'id': 5,
#                             'multiallelic': False,
#                             'needs_verification': False,
#                             'needs_verification_checks': {'allele_ratio': True,
#                                                           'dp': True,
#                                                           'hts': True,
#                                                           'pass': True,
#                                                           'snp': True},
#                             'sequencing_depth': 187,
#                             'type': 'Heterozygous',
#                             'variant_quality': 5000},
#                'id': 2,
#                'identifier': 'brca_sample_1',
#                'mother_id': None,
#                'proband': True,
#                'sample_type': 'HTS',
#                'sex': None,
#                'sibling_id': None}],
#   'start_position': 32890665,
#   'tags': ['has_references'],
#   'vcf_alt': 'A',
#   'vcf_pos': 32890666,
#   'vcf_ref': 'T'},
#  {'allele_assessment': {'allele_id': 6,
#                         'analysis_id': 2,
#                         'annotation_id': 6,
#                         'attachment_ids': [],
#                         'classification': 'U',
#                         'custom_annotation_id': None,
#                         'date_created': '2020-10-19T10:50:26.990666+00:00',
#                         'date_superceeded': None,
#                         'evaluation': {'acmg': {'included': [],
#                                                 'suggested': [{'code': 'REQ_GP_last_exon_not_important',
#                                                                'match': ['LENI'],
#                                                                'op': '$in',
#                                                                'source': 'genepanel.last_exon_important'},
#                                                               {'code': 'REQ_GP_LOF_missense',
#                                                                'match': ['ANY'],
#                                                                'op': '$in',
#                                                                'source': 'genepanel.disease_mode'},
#                                                               {'code': 'REQ_missense',
# ...
#                                                                                     'benign',
#                                                      'last_evaluated': '14/06/2016',
#                                                      'rcv': 'SCV000383605',
#                                                      'submitter': 'Illumina',
#                                                      'traitnames': 'Fanconi '
#                                                                    'Anemia',
#                                                      'variant_id': ''},
#                                                     {'clinical_significance_descr': 'Benign/Likely '
#                                                                                     'benign',
#                                                      'last_evaluated': '03/01/2018',
#                                                      'rcv': 'RCV000167850',
#                                                      'submitter': '',
#                                                      'traitnames': 'Hereditary '
#                                                                    'breast and '
#                                                                    'ovarian '
#                                                                    'cancer '
#                                                                    'syndrome',
#                                                      'variant_id': '51234'},
#                                                     {'clinical_significance_descr': 'Likely '
#                                                                                     'benign',
#                                                      'last_evaluated': '02/04/2015',
#                                                      'rcv': 'SCV000683467',
#                                                      'submitter': 'Color '
#                                                                   'Genomics, '
#                                                                   'Inc.',
#                                                      'traitnames': '',
#                                                      'variant_id': ''}],
#                                           'variant_description': 'reviewed by '
#                                                                  'expert panel',
#                                           'variant_id': 51234},
#                               'HGMD': {'acc_num': 'CM173583',
#                                        'codon': 66,
#                                        'disease': 'Breast and/or ovarian '
#                                                   'cancer',
#                                        'tag': 'DM?'}},
#                  'filtered_transcripts': ['NM_000059.3'],
#                  'frequencies': {'1000g': {'freq': {'AFR': 0.0,
#                                                     'AMR': 0.0,
#                                                     'EAS': 0.0,
#                                                     'EUR': 0.001,
#                                                     'G': 0.002,
#                                                     'SAS': 0.0092}},
#                                  'ExAC': {'count': {'AFR': 0,
#                                                     'AMR': 1,
#                                                     'EAS': 0,
#                                                     'FIN': 0,
#                                                     'G': 130,
#                                                     'Het': 124,
#                                                     'NFE': 13,
#                                                     'OTH': 0,
#                                                     'SAS': 116},
#                                           'freq': {'AFR': 0.0,
#                                                    'AMR': 8.644536652835408e-05,
#                                                    'EAS': 0.0,
#                                                    'FIN': 0.0,
#                                                    'G': 0.0010724125983732325,
#                                                    'NFE': 0.00019503705704083775,
#                                                    'OTH': 0.0,
#                                                    'SAS': 0.007027747485762753},
#                                           'hom': {'AFR': 0,
#                                                   'AMR': 0,
#                                                   'EAS': 0,
#                                                   'FIN': 0,
#                                                   'G': 3,
#                                                   'NFE': 0,
#                                                   'OTH': 0,
#                                                   'SAS': 3},
#                                           'num': {'AFR': 10322,
#                                                   'AMR': 11568,
#                                                   'EAS': 8652,
#                                                   'FIN': 6614,
#                                                   'G': 121222,
#                                                   'NFE': 66654,
#                                                   'OTH': 906,
#                                                   'SAS': 16506}},
#                                  'GNOMAD_EXOMES': {'count': {'AFR': 0,
#                                                              'AMR': 3,
#                                                              'ASJ': 0,
#                                                              'EAS': 0,
#                                                              'FIN': 0,
#                                                              'Female': 73,
#                                                              'G': 273,
#                                                              'Male': 200,
#                                                              'NFE': 30,
#                                                              'OTH': 3,
#                                                              'SAS': 237},
#                                                    'filter': {'G': ['PASS']},
#                                                    'freq': {'AFR': 0.0,
#                                                             'AMR': 8.933889219773674e-05,
#                                                             'ASJ': 0.0,
#                                                             'EAS': 0.0,
#                                                             'FIN': 0.0,
#                                                             'Female': 0.0006557082547381659,
#                                                             'G': 0.001108836574547936,
#                                                             'Male': 0.0014828654892714683,
#                                                             'NFE': 0.00026863907444884215,
#                                                             'OTH': 0.0005470459518599562,
#                                                             'SAS': 0.007699805068226121},
#                                                    'hom': {'AFR': 0,
#                                                            'AMR': 0,
#                                                            'ASJ': 0,
#                                                            'EAS': 0,
#                                                            'FIN': 0,
#                                                            'Female': 3,
#                                                            'G': 5,
#                                                            'Male': 2,
#                                                            'NFE': 0,
#                                                            'OTH': 0,
#                                                            'SAS': 5},
#                                                    'num': {'AFR': 15296,
#                                                            'AMR': 33580,
#                                                            'ASJ': 9848,
#                                                            'EAS': 17246,
#                                                            'FIN': 22296,
#                                                            'Female': 111330,
#                                                            'G': 246204,
#                                                            'Male': 134874,
#                                                            'NFE': 111674,
#                                                            'OTH': 5484,
#                                                            'SAS': 30780}},
#                                  'GNOMAD_GENOMES': {'count': {'AFR': 0,
#                                                               'AMR': 0,
#                                                               'ASJ': 0,
#                                                               'EAS': 0,
#                                                               'FIN': 0,
#                                                               'Female': 2,
#                                                               'G': 4,
#                                                               'Male': 2,
#                                                               'NFE': 4,
#                                                               'OTH': 0},
#                                                     'filter': {'G': ['PASS']},
#                                                     'freq': {'AFR': 0.0,
#                                                              'AMR': 0.0,
#                                                              'ASJ': 0.0,
#                                                              'EAS': 0.0,
#                                                              'FIN': 0.0,
#                                                              'Female': 0.0001443209698369173,
#                                                              'G': 0.0001291155584247902,
#                                                              'Male': 0.00011680878402055835,
#                                                              'NFE': 0.00026652452025586353,
#                                                              'OTH': 0.0},
#                                                     'hom': {'AFR': 0,
#                                                             'AMR': 0,
#                                                             'ASJ': 0,
#                                                             'EAS': 0,
#                                                             'FIN': 0,
#                                                             'Female': 0,
#                                                             'G': 0,
#                                                             'Male': 0,
#                                                             'NFE': 0,
#                                                             'OTH': 0},
#                                                     'num': {'AFR': 8736,
#                                                             'AMR': 838,
#                                                             'ASJ': 302,
#                                                             'EAS': 1622,
#                                                             'FIN': 3494,
#                                                             'Female': 13858,
#                                                             'G': 30980,
#                                                             'Male': 17122,
#                                                             'NFE': 15008,
#                                                             'OTH': 980}},
#                                  'esp6500': {'freq': {'AA': 0.0, 'EA': 0.0003}},
#                                  'inDB': {'count': {'OUST1': 1},
#                                           'filter': {'OUST1': ['PASS']},
#                                           'freq': {'OUST1': 0.0017006802721088435},
#                                           'hom': {'OUST1': 0},
#                                           'indications': {'OUSWES': {'OUST1': {'TrioPU': '1'}}},
#                                           'num': {'OUST1': 588}}},
#                  'prediction': {},
#                  'references': [{'pubmed_id': 28324225,
#                                  'source_info': {'HGMD': 'Primary literature '
#                                                          'report. Classified '
#                                                          'as VUS3 (IARC).'},
#                                  'sources': ['HGMD']},
#                                 {'pubmed_id': 18844490,
#                                  'source_info': {},
#                                  'sources': ['CLINVAR']},
#                                 {'pubmed_id': 28492532,
#                                  'source_info': {},
#                                  'sources': ['CLINVAR']},
#                                 {'pubmed_id': 19471317,
#                                  'source_info': {},
#                                  'sources': ['CLINVAR']},
#                                 {'pubmed_id': 10923033,
#                                  'source_info': {},
#                                  'sources': ['CLINVAR']}],
#                  'schema_version': 1,
#                  'transcripts': [{'HGVSc': 'c.198A>G',
#                                   'HGVSc_short': 'c.198A>G',
#                                   'HGVSp': 'c.198A>G(p.=)',
#                                   'amino_acids': 'Q',
#                                   'coding_region_distance': 0,
#                                   'codons': 'caA/caG',
#                                   'consequences': ['synonymous_variant'],
#                                   'dbsnp': ['rs28897700'],
#                                   'exon': '3/27',
#                                   'exon_distance': 0,
#                                   'hgnc_id': 1101,
#                                   'in_last_exon': 'no',
#                                   'is_canonical': True,
#                                   'protein': 'NM_000059.3',
#                                   'strand': 1,
#                                   'symbol': 'BRCA2',
#                                   'transcript': 'NM_000059.3'}],
#                  'worst_consequence': ['NM_000059.3']},
#   'change_from': 'A',
#   'change_to': 'G',
#   'change_type': 'SNP',
#   'chromosome': '13',
#   'genome_reference': 'GRCh37',
#   'id': 8,
#   'open_end_position': 32893344,
#   'samples': [{'affected': True,
#                'date_deposited': '2020-10-19T10:46:43.434024+00:00',
#                'family_id': None,
#                'father_id': None,
#                'genotype': {'allele_depth': {'G': 80, 'REF (A)': 107},
#                             'allele_ratio': 0.42780748663101603,
#                             'filter_status': 'PASS',
#                             'formatted': 'A/G',
#                             'genotype_quality': 99,
#                             'id': 8,
#                             'multiallelic': False,
#                             'needs_verification': False,
#                             'needs_verification_checks': {'allele_ratio': True,
#                                                           'dp': True,
#                                                           'hts': True,
#                                                           'pass': True,
#                                                           'snp': True},
#                             'sequencing_depth': 187,
#                             'type': 'Heterozygous',
#                             'variant_quality': 5000},
#                'id': 2,
#                'identifier': 'brca_sample_1',
#                'mother_id': None,
#                'proband': True,
#                'sample_type': 'HTS',
#                'sex': None,
#                'sibling_id': None}],
#   'start_position': 32893343,
#   'tags': ['has_references'],
#   'vcf_alt': 'G',
#   'vcf_pos': 32893344,
#   'vcf_ref': 'A'}]

# %%
len(response)
# Out:
# 6

# %%
# api/v1/workflows/analyses/2/collisions/?allele_ids=3%2C4%2C5%2C6%2C7%2C8
query_url = 'api/v1/workflows/analyses/2/collisions/'
payload = {'allele_ids': allele_ids}
response = session.get('{}/{}'.format(url, query_url), params=payload)
response = json.loads(response.content.decode('utf-8'))
pprint(response)
# Out:
# []

# %%
#POST - http://localhost:5001/api/v1/acmg/alleles/ - 
json_data = {"allele_ids":["3","4","5","6","7","8"],"gp_name":"HBOCUTV","gp_version":"v01","referenceassessments":[]}

query_url = 'api/v1/acmg/alleles/' 
response = session.post('{}/{}'.format(url, query_url), json=json_data)
response = json.loads(response.content.decode('utf-8'))
pprint(response)
# Out:
# {'3': {'codes': [{'code': 'REQ_GP_last_exon_not_important',
#                   'match': ['LENI'],
#                   'op': '$in',
#                   'source': 'genepanel.last_exon_important',
#                   'value': ['LENI']},
#                  {'code': 'REQ_GP_LOF_missense',
#                   'match': ['ANY'],
#                   'op': '$in',
#                   'source': 'genepanel.disease_mode',
#                   'value': ['ANY']},
#                  {'code': 'REQ_not_in_last_exon',
#                   'match': ['no'],
#                   'op': '$in',
#                   'source': 'transcript.in_last_exon',
#                   'value': ['no']},
#                  {'code': 'REQ_null_variant',
#                   'match': ['stop_gained'],
#                   'op': '$in',
#                   'source': 'transcript.consequences',
#                   'value': ['start_lost',
#                             'initiator_codon_variant',
#                             'transcript_ablation',
#                             'splice_donor_variant',
#                             'splice_acceptor_variant',
#                             'stop_gained',
#                             'frameshift_variant']},
#                  {'code': 'REQ_no_freq',
#                   'match': ['null_freq'],
#                   'op': '$in',
#                   'source': 'frequencies.commonness',
#                   'value': ['null_freq']},
#                  {'code': 'PVS1', 'source': None},
#                  {'code': 'PPxPM2', 'source': None}]},
#  '4': {'codes': [{'code': 'REQ_GP_last_exon_not_important',
#                   'match': ['LENI'],
#                   'op': '$in',
#                   'source': 'genepanel.last_exon_important',
#                   'value': ['LENI']},
#                  {'code': 'REQ_GP_LOF_missense',
#                   'match': ['ANY'],
#                   'op': '$in',
#                   'source': 'genepanel.disease_mode',
#                   'value': ['ANY']},
#                  {'code': 'REQ_not_in_last_exon',
#                   'match': ['no'],
#                   'op': '$in',
#                   'source': 'transcript.in_last_exon',
#                   'value': ['no']},
#                  {'code': 'REQ_null_variant',
#                   'match': ['frameshift_variant'],
#                   'op': '$in',
#                   'source': 'transcript.consequences',
#                   'value': ['start_lost',
#                             'initiator_codon_variant',
#                             'transcript_ablation',
#                             'splice_donor_variant',
#                             'splice_acceptor_variant',
#                             'stop_gained',
#                             'frameshift_variant']},
#                  {'code': 'REQ_no_freq',
#                   'match': ['null_freq'],
#                   'op': '$in',
#                   'source': 'frequencies.commonness',
#                   'value': ['null_freq']},
#                  {'code': 'PVS1', 'source': None},
#                  {'code': 'PPxPM2', 'source': None}]},
#  '5': {'codes': [{'code': 'REQ_GP_last_exon_not_important',
#                   'match': ['LENI'],
#                   'op': '$in',
#                   'source': 'genepanel.last_exon_important',
#                   'value': ['LENI']},
#                  {'code': 'REQ_GP_LOF_missense',
#                   'match': ['ANY'],
#                   'op': '$in',
#                   'source': 'genepanel.disease_mode',
#                   'value': ['ANY']},
#                  {'code': 'REQ_not_in_last_exon',
#                   'match': ['no'],
#                   'op': '$in',
#                   'source': 'transcript.in_last_exon',
#                   'value': ['no']},
#                  {'code': 'REQ_null_variant',
#                   'match': ['splice_donor_variant'],
#                   'op': '$in',
#                   'source': 'transcript.consequences',
#                   'value': ['start_lost',
#                             'initiator_codon_variant',
#                             'transcript_ablation',
#                             'splice_donor_variant',
#                             'splice_acceptor_variant',
#                             'stop_gained',
#                             'frameshift_variant']},
#                  {'code': 'REQ_no_freq',
#                   'match': ['null_freq'],
#                   'op': '$in',
#                   'source': 'frequencies.commonness',
#                   'value': ['null_freq']},
#                  {'code': 'PVS1', 'source': None},
#                  {'code': 'PPxPM2', 'source': None}]},
#  '6': {'codes': [{'code': 'REQ_GP_last_exon_not_important',
#                   'match': ['LENI'],
#                   'op': '$in',
#                   'source': 'genepanel.last_exon_important',
#                   'value': ['LENI']},
#                  {'code': 'REQ_GP_LOF_missense',
#                   'match': ['ANY'],
#                   'op': '$in',
#                   'source': 'genepanel.disease_mode',
#                   'value': ['ANY']},
#                  {'code': 'REQ_missense',
#                   'match': ['missense_variant'],
#                   'op': '$in',
#                   'source': 'transcript.consequences',
#                   'value': ['missense_variant', 'protein_altering_variant']},
#                  {'code': 'REQ_not_in_last_exon',
#                   'match': ['no'],
#                   'op': '$in',
#                   'source': 'transcript.in_last_exon',
#                   'value': ['no']}]},
#  '7': {'codes': [{'code': 'REQ_GP_last_exon_not_important',
#                   'match': ['LENI'],
#                   'op': '$in',
#                   'source': 'genepanel.last_exon_important',
#                   'value': ['LENI']},
#                  {'code': 'REQ_GP_LOF_missense',
#                   'match': ['ANY'],
#                   'op': '$in',
#                   'source': 'genepanel.disease_mode',
#                   'value': ['ANY']},
#                  {'code': 'REQ_not_in_last_exon',
#                   'match': ['no'],
#                   'op': '$in',
#                   'source': 'transcript.in_last_exon',
#                   'value': ['no']},
#                  {'code': 'REQ_null_variant',
#                   'match': ['stop_gained'],
#                   'op': '$in',
#                   'source': 'transcript.consequences',
#                   'value': ['start_lost',
#                             'initiator_codon_variant',
#                             'transcript_ablation',
#                             'splice_donor_variant',
#                             'splice_acceptor_variant',
#                             'stop_gained',
#                             'frameshift_variant']},
#                  {'code': 'REQ_no_freq',
#                   'match': ['null_freq'],
#                   'op': '$in',
#                   'source': 'frequencies.commonness',
#                   'value': ['null_freq']},
#                  {'code': 'PVS1', 'source': None},
#                  {'code': 'PPxPM2', 'source': None}]},
#  '8': {'codes': [{'code': 'REQ_GP_last_exon_not_important',
#                   'match': ['LENI'],
#                   'op': '$in',
#                   'source': 'genepanel.last_exon_important',
#                   'value': ['LENI']},
#                  {'code': 'REQ_GP_LOF_missense',
#                   'match': ['ANY'],
#                   'op': '$in',
#                   'source': 'genepanel.disease_mode',
#                   'value': ['ANY']},
#                  {'code': 'REQ_less_common',
#                   'match': ['less_common'],
#                   'op': '$in',
#                   'source': 'frequencies.commonness',
#                   'value': ['less_common']},
#                  {'code': 'REQ_no_aa_change',
#                   'match': ['synonymous_variant'],
#                   'op': '$in',
#                   'source': 'transcript.consequences',
#                   'value': ['stop_retained_variant',
#                             'start_retained_variant',
#                             'synonymous_variant']},
#                  {'code': 'REQ_not_in_last_exon',
#                   'match': ['no'],
#                   'op': '$in',
#                   'source': 'transcript.in_last_exon',
#                   'value': ['no']}]}}
