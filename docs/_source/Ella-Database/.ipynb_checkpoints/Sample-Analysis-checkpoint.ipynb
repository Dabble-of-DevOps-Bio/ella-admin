# %%
import os
import sqlalchemy as sa
from sqlalchemy import create_engine
from sqlalchemy import inspect
import json
from pprint import pprint
import pandas as pd

# %%
os.environ.get('DB_URL')
# Out:
# 'postgresql://postgres:password123@postgresql/postgres'

# %%
engine = sa.create_engine(os.environ.get('DB_URL'))

# %%
# %load_ext sql

# %%
# %sql postgresql://postgres:password123@postgresql/postgres

# %%
# Get column information
def get_column_info(tables):
    for table in tables:
        print(table)
        columns = inspector.get_columns(table)
        pprint(columns)

db_uri = os.environ.get('DB_URL')
engine = create_engine(db_uri)

inspector = inspect(engine)

# Get table information
tables = inspector.get_table_names()
pprint(tables)
# Out:
# ['annotation',
#  'gene',
#  'allele',
#  'transcript',
#  'phenotype',
#  'usergroup',
#  'genepanel_transcript',
#  'usergroupgenepanel',
#  'user',
#  'customannotation',
#  'usersession',
#  'useroldpassword',
#  'attachment',
#  'genotype',
#  'alleleinterpretation',
#  'reference',
#  'interpretationstatehistory',
#  'resourcelog',
#  'alleleassessmentattachment',
#  'alleleassessmentreferenceassessment',
#  'alembic_version',
#  'analysisinterpretation',
#  'annotationjob',
#  'genepanel',
#  'genepanel_phenotype',
#  'sample',
#  'analysis',
#  'broadcast',
#  'genotypesampledata',
#  'clilog',
#  'usergroupfilterconfig',
#  'jsonschema',
#  'filterconfig',
#  'alleleinterpretationsnapshot',
#  'analysisinterpretationsnapshot',
#  'interpretationlog',
#  'alleleassessment',
#  'allelereport',
#  'referenceassessment',
#  'geneassessment',
#  'annotationshadowfrequency',
#  'annotationshadowtranscript']

# %% [markdown]
# ## Report Generation
#
# Most of the time a report is generated for a particular sample.
#
# Sample Id -> Analysis Id -> List(Interpretation Ids) -> List(Allele Id)

# %%
# %%sql
#
# SELECT * FROM sample;
# Out:
#  * postgresql://postgres:***@postgresql/postgres
# 7 rows affected.
# [(1, 'brca_allfiltered', 1, 'HTS', datetime.datetime(2020, 10, 19, 7, 29, 42, 471284, tzinfo=psycopg2.tz.FixedOffsetTimezone(offset=0, name=None)), True, None, None, None, None, True, None),
#  (2, 'brca_sample_1', 2, 'HTS', datetime.datetime(2020, 10, 19, 7, 29, 46, 227075, tzinfo=psycopg2.tz.FixedOffsetTimezone(offset=0, name=None)), True, None, None, None, None, True, None),
#  (4, 'brca_sample_3', 5, 'HTS', datetime.datetime(2020, 10, 19, 7, 30, 2, 294520, tzinfo=psycopg2.tz.FixedOffsetTimezone(offset=0, name=None)), True, None, None, None, None, True, None),
#  (5, 'brca_sample_1', 6, 'HTS', datetime.datetime(2020, 10, 19, 7, 30, 5, 715108, tzinfo=psycopg2.tz.FixedOffsetTimezone(offset=0, name=None)), True, None, None, None, None, True, None),
#  (6, 'brca_sample_master', 7, 'HTS', datetime.datetime(2020, 10, 19, 7, 30, 9, 451317, tzinfo=psycopg2.tz.FixedOffsetTimezone(offset=0, name=None)), True, None, None, None, None, True, None),
#  (7, 'brca_sample_2', 8, 'HTS', datetime.datetime(2020, 10, 19, 7, 30, 12, 751708, tzinfo=psycopg2.tz.FixedOffsetTimezone(offset=0, name=None)), True, None, None, None, None, True, None),
#  (8, 'brca_sample_master', 9, 'HTS', datetime.datetime(2020, 10, 19, 7, 30, 16, 355499, tzinfo=psycopg2.tz.FixedOffsetTimezone(offset=0, name=None)), True, None, None, None, None, True, None)]

# %% [markdown]
# ## Analysis brca_sample_1.HBOCUTV_v01
#
# Since any sample can duplicate records with more than 1 analysis, make sure you are getting the correct analysis and the correct. On the UI there needs to be a filter by sample_name, sample_type, date_deposited, genepanel name, and/or genepanel version.
#
# Generally the Sample Name is going to be read in from a LIMs system somewhere anyways.

# %%
# make sure to use single quotes, '', not ""

report_data = {}

# %%
sample = %sql select * from sample where analysis_id = 2 AND identifier = 'brca_sample_1';
sample_df = sample.DataFrame()
sample_df
# Out:
#  * postgresql://postgres:***@postgresql/postgres
# 1 rows affected.
#    id     identifier  analysis_id sample_type  \
# 0   2  brca_sample_1            2         HTS
#
#                     date_deposited  affected family_id father_id mother_id  \
# 0 2020-10-19 07:29:46.227075+00:00      True      None      None      None
#
#   sibling_id  proband   sex
# 0       None     True  None

# %%
report_data['sample'] = sample_df.to_dict('records')

# %%
analysis = %sql SELECT * FROM analysis where name = 'brca_sample_1.HBOCUTV_v01';
analysis_df = analysis.DataFrame()
analysis_df
# Out:
#  * postgresql://postgres:***@postgresql/postgres
# 1 rows affected.
#    id                       name genepanel_name genepanel_version warnings  \
# 0   2  brca_sample_1.HBOCUTV_v01        HBOCUTV               v01     None
#
#   report                   date_deposited properties date_requested
# 0   None 2020-10-19 07:29:46.204898+00:00       None           None

# %%
report_data['analysis'] = analysis_df.to_dict('records')

# %%
# At some point I will want to filter on analyses that are complete

analysis_interpretation = %sql select * from analysisinterpretation where analysis_id = 2;
analysis_interprtetation_df = analysis_interpretation.DataFrame()
analysis_interprtetation_df
# Out:
#  * postgresql://postgres:***@postgresql/postgres
# 1 rows affected.
#    id genepanel_name genepanel_version  \
# 0   2        HBOCUTV               v01
#
#                                           user_state  \
# 0  {'allele': {'3': {'sections': {}, 'allele_id':...
#
#                                                state   status  \
# 0  {'allele': {'3': {'report': {'included': True}...  Ongoing
#
#                   date_last_update                     date_created  \
# 0 2020-10-19 08:01:33.706453+00:00 2020-10-19 07:29:46.217740+00:00
#
#    analysis_id  user_id finalized workflow_status
# 0            2        1      None  Interpretation

# %%
report_data['analysis_interprtetation'] = analysis_interprtetation_df.to_dict('records')

# %%
allele_assessment = %sql select * from alleleassessment where analysis_id = 2;
allele_assessment_df = allele_assessment.DataFrame()

report_data['allele_assessment'] = allele_assessment_df.to_dict('records')

allele_assessment_df
# Out:
#  * postgresql://postgres:***@postgresql/postgres
# 6 rows affected.
#    id classification                                         evaluation  \
# 0   1              4  {'acmg': {'included': [{'op': None, 'code': 'P...
# 1   2              4  {'acmg': {'included': [{'op': None, 'code': 'P...
# 2   3              4  {'acmg': {'included': [{'op': None, 'code': 'P...
# 3   4              U  {'acmg': {'included': [], 'suggested': [{'op':...
# 4   5              4  {'acmg': {'included': [{'op': None, 'code': 'P...
# 5   6              U  {'acmg': {'included': [], 'suggested': [{'op':...
#
#    user_id                     date_created date_superceeded  \
# 0        1 2020-10-19 07:43:59.585285+00:00             None
# 1        1 2020-10-19 07:44:15.013829+00:00             None
# 2        1 2020-10-19 07:44:30.335239+00:00             None
# 3        1 2020-10-19 07:44:43.334923+00:00             None
# 4        1 2020-10-19 07:44:58.945348+00:00             None
# 5        1 2020-10-19 07:45:11.324654+00:00             None
#
#   previous_assessment_id  allele_id genepanel_name genepanel_version  \
# 0                   None          3        HBOCUTV               v01
# 1                   None          4        HBOCUTV               v01
# 2                   None          5        HBOCUTV               v01
# 3                   None          6        HBOCUTV               v01
# 4                   None          7        HBOCUTV               v01
# 5                   None          8        HBOCUTV               v01
#
#    analysis_id  annotation_id custom_annotation_id  usergroup_id
# 0            2              3                 None             1
# 1            2              4                 None             1
# 2            2              5                 None             1
# 3            2              6                 None             1
# 4            2              7                 None             1
# 5            2              8                 None             1

# %%
# Now let's grab the allele ids
allele_ids = allele_assessment_df['allele_id'].tolist() 
query = sa.text(""" 
                SELECT *
                FROM annotation
                WHERE allele_id IN :values; 
""")
query = query.bindparams(values=tuple(allele_ids))
allele_annotation_df = pd.read_sql(query, engine)
allele_annotation_df
# Out:
#    id  allele_id                                        annotations  \
# 0   3          3  {'external': {'HGMD': {'tag': 'DM', 'codon': 4...
# 1   4          4  {'external': {'HGMD': {'tag': 'DM', 'codon': 1...
# 2   5          5  {'external': {'HGMD': {'tag': 'DM', 'acc_num':...
# 3   6          6  {'external': {'HGMD': {'tag': 'DM', 'codon': 2...
# 4   7          7  {'external': {'HGMD': {'tag': 'DM', 'codon': 3...
# 5   8          8  {'external': {'HGMD': {'tag': 'DM?', 'codon': ...
#
#   previous_annotation_id date_superceeded                     date_created  \
# 0                   None             None 2020-10-19 07:29:46.327638+00:00
# 1                   None             None 2020-10-19 07:29:46.327657+00:00
# 2                   None             None 2020-10-19 07:29:46.327665+00:00
# 3                   None             None 2020-10-19 07:29:46.327672+00:00
# 4                   None             None 2020-10-19 07:29:46.327678+00:00
# 5                   None             None 2020-10-19 07:29:46.327685+00:00
#
#    schema_version
# 0               1
# 1               1
# 2               1
# 3               1
# 4               1
# 5               1

# %%
report_data['allele_annotation'] = allele_annotation_df.to_dict('records')

# %% [markdown]
# ## Sample Analysis DataSet
#
# The dataset from a sample analysis should look like:

# %%
pprint(report_data.keys())
# Out:
# dict_keys(['sample', 'analysis', 'analysis_interprtetation', 'allele_assessment', 'allele_annotation'])

# %%
report_data
# Out:
# {'sample': [{'id': 2,
#    'identifier': 'brca_sample_1',
#    'analysis_id': 2,
#    'sample_type': 'HTS',
#    'date_deposited': Timestamp('2020-10-19 07:29:46.227075+0000', tz='psycopg2.tz.FixedOffsetTimezone(offset=0, name=None)'),
#    'affected': True,
#    'family_id': None,
#    'father_id': None,
#    'mother_id': None,
#    'sibling_id': None,
#    'proband': True,
#    'sex': None}],
#  'analysis': [{'id': 2,
#    'name': 'brca_sample_1.HBOCUTV_v01',
#    'genepanel_name': 'HBOCUTV',
#    'genepanel_version': 'v01',
#    'warnings': None,
#    'report': None,
#    'date_deposited': Timestamp('2020-10-19 07:29:46.204898+0000', tz='psycopg2.tz.FixedOffsetTimezone(offset=0, name=None)'),
#    'properties': None,
#    'date_requested': None}],
#  'analysis_interprtetation': [{'id': 2,
#    'genepanel_name': 'HBOCUTV',
#    'genepanel_version': 'v01',
#    'user_state': {'allele': {'3': {'sections': {},
#       'allele_id': 3,
#       'showExcludedReferences': False},
#      '4': {'sections': {}, 'allele_id': 4, 'showExcludedReferences': False},
#      '5': {'sections': {}, 'allele_id': 5, 'showExcludedReferences': False},
#      '6': {'sections': {}, 'allele_id': 6, 'showExcludedReferences': False},
#      '7': {'sections': {}, 'allele_id': 7, 'showExcludedReferences': False},
#      '8': {'sections': {}, 'allele_id': 8, 'showExcludedReferences': False}}},
#    'state': {'allele': {'3': {'report': {'included': True},
#       'analysis': {'comment': '',
#        'notrelevant': None,
#        'verification': 'verified'},
#       'workflow': {'reviewed': True},
#       'allele_id': 3,
#       'allelereport': {'evaluation': {'comment': ''}, 'copiedFromId': 1},
#       'alleleassessment': {'reuse': True, 'allele_id': 3, 'reuseCheckedId': 1},
#       'referenceassessments': []},
#      '4': {'report': {'included': True},
#       'analysis': {'comment': '',
#        'notrelevant': None,
#        'verification': 'verified'},
#       'workflow': {'reviewed': True},
#       'allele_id': 4,
#       'allelereport': {'evaluation': {'comment': ''}, 'copiedFromId': 2},
#       'alleleassessment': {'reuse': True, 'allele_id': 4, 'reuseCheckedId': 2},
#       'referenceassessments': []},
#      '5': {'report': {'included': True},
#       'analysis': {'comment': '',
#        'notrelevant': None,
#        'verification': 'verified'},
#       'workflow': {'reviewed': True},
#       'allele_id': 5,
#       'allelereport': {'evaluation': {'comment': ''}, 'copiedFromId': 3},
#       'alleleassessment': {'reuse': True, 'allele_id': 5, 'reuseCheckedId': 3},
#       'referenceassessments': []},
#      '6': {'report': {'included': False},
#       'analysis': {'comment': '',
#        'notrelevant': None,
#        'verification': 'verified'},
#       'workflow': {'reviewed': True},
#       'allele_id': 6,
#       'allelereport': {'evaluation': {'comment': ''}, 'copiedFromId': 4},
#       'alleleassessment': {'reuse': True, 'allele_id': 6, 'reuseCheckedId': 4},
#       'referenceassessments': []},
#      '7': {'report': {'included': True},
#       'analysis': {'comment': '',
#        'notrelevant': None,
#        'verification': 'verified'},
#       'workflow': {'reviewed': True},
#       'allele_id': 7,
#       'allelereport': {'evaluation': {'comment': ''}, 'copiedFromId': 5},
#       'alleleassessment': {'reuse': True, 'allele_id': 7, 'reuseCheckedId': 5},
#       'referenceassessments': []},
#      '8': {'report': {'included': False},
#       'analysis': {'comment': '',
#        'notrelevant': None,
#        'verification': 'verified'},
#       'workflow': {'reviewed': True},
#       'allele_id': 8,
#       'allelereport': {'evaluation': {'comment': ''}, 'copiedFromId': 6},
#       'alleleassessment': {'reuse': True, 'allele_id': 8, 'reuseCheckedId': 6},
#       'referenceassessments': []}},
#     'filterconfigId': 1,
#     'manuallyAddedAlleles': []},
#    'status': 'Ongoing',
#    'date_last_update': Timestamp('2020-10-19 08:01:33.706453+0000', tz='psycopg2.tz.FixedOffsetTimezone(offset=0, name=None)'),
#    'date_created': Timestamp('2020-10-19 07:29:46.217740+0000', tz='psycopg2.tz.FixedOffsetTimezone(offset=0, name=None)'),
#    'analysis_id': 2,
#    'user_id': 1,
#    'finalized': None,
#    'workflow_status': 'Interpretation'}],
#  'allele_assessment': [{'id': 1,
#    'classification': '4',
#    'evaluation': {'acmg': {'included': [{'op': None,
#        'code': 'PVS1',
#        'uuid': '7ad2d394-73bb-4df6-a878-2948ca839f36',
#        'match': None,
#        'source': 'suggested',
#        'comment': ''},
#       {'op': None,
#        'code': 'PPxPM2',
#        'uuid': '49d9a1c5-3a8d-4c5f-b106-65317f021d3e',
#        'match': None,
#        'source': 'suggested',
#        'comment': ''}],
#      'suggested': [{'op': '$in',
#        'code': 'REQ_GP_last_exon_not_important',
#        'match': ['LENI'],
#        'source': 'genepanel.last_exon_important'},
#       {'op': '$in',
#        'code': 'REQ_GP_LOF_missense',
#        'match': ['ANY'],
#        'source': 'genepanel.disease_mode'},
#       {'op': '$in',
#        'code': 'REQ_not_in_last_exon',
#        'match': ['no'],
#        'source': 'transcript.in_last_exon'},
#       {'op': '$in',
#        'code': 'REQ_null_variant',
#        'match': ['stop_gained'],
#        'source': 'transcript.consequences'},
#       {'op': '$in',
#        'code': 'REQ_no_freq',
#        'match': ['null_freq'],
#        'source': 'frequencies.commonness'},
#       {'op': None, 'code': 'PVS1', 'match': None, 'source': None},
#       {'op': None, 'code': 'PPxPM2', 'match': None, 'source': None}],
#      'suggested_classification': 4},
#     'external': {'comment': ''},
#     'frequency': {'comment': ''},
#     'reference': {'comment': ''},
#     'prediction': {'comment': ''},
#     'classification': {'comment': ''}},
#    'user_id': 1,
#    'date_created': Timestamp('2020-10-19 07:43:59.585285+0000', tz='psycopg2.tz.FixedOffsetTimezone(offset=0, name=None)'),
#    'date_superceeded': None,
#    'previous_assessment_id': None,
#    'allele_id': 3,
#    'genepanel_name': 'HBOCUTV',
#    'genepanel_version': 'v01',
#    'analysis_id': 2,
#    'annotation_id': 3,
#    'custom_annotation_id': None,
#    'usergroup_id': 1},
#   {'id': 2,
#    'classification': '4',
#    'evaluation': {'acmg': {'included': [{'op': None,
#        'code': 'PVS1',
#        'uuid': '3dfbb5e1-9cf5-44b7-9c9d-baf91ca8341d',
#        'match': None,
#        'source': 'suggested',
#        'comment': ''},
#       {'op': None,
#        'code': 'PPxPM2',
#        'uuid': '9f74e9e3-33ea-4f24-9be8-ea4120135a36',
#        'match': None,
#        'source': 'suggested',
#        'comment': ''}],
#      'suggested': [{'op': '$in',
#        'code': 'REQ_GP_last_exon_not_important',
#        'match': ['LENI'],
#        'source': 'genepanel.last_exon_important'},
#       {'op': '$in',
#        'code': 'REQ_GP_LOF_missense',
#        'match': ['ANY'],
#        'source': 'genepanel.disease_mode'},
#       {'op': '$in',
#        'code': 'REQ_not_in_last_exon',
#        'match': ['no'],
#        'source': 'transcript.in_last_exon'},
#       {'op': '$in',
#        'code': 'REQ_null_variant',
#        'match': ['frameshift_variant'],
#        'source': 'transcript.consequences'},
#       {'op': '$in',
#        'code': 'REQ_no_freq',
#        'match': ['null_freq'],
#        'source': 'frequencies.commonness'},
#       {'op': None, 'code': 'PVS1', 'match': None, 'source': None},
#       {'op': None, 'code': 'PPxPM2', 'match': None, 'source': None}],
#      'suggested_classification': 4},
#     'external': {'comment': ''},
#     'frequency': {'comment': ''},
#     'reference': {'comment': ''},
#     'prediction': {'comment': ''},
#     'classification': {'comment': ''}},
#    'user_id': 1,
#    'date_created': Timestamp('2020-10-19 07:44:15.013829+0000', tz='psycopg2.tz.FixedOffsetTimezone(offset=0, name=None)'),
#    'date_superceeded': None,
#    'previous_assessment_id': None,
#    'allele_id': 4,
#    'genepanel_name': 'HBOCUTV',
#    'genepanel_version': 'v01',
#    'analysis_id': 2,
#    'annotation_id': 4,
#    'custom_annotation_id': None,
#    'usergroup_id': 1},
#   {'id': 3,
#    'classification': '4',
#    'evaluation': {'acmg': {'included': [{'op': None,
#        'code': 'PVS1',
#        'uuid': '9517fec5-6196-4ae8-bb0a-1fd28c1cade0',
#        'match': None,
#        'source': 'suggested',
#        'comment': ''},
#       {'op': None,
#        'code': 'PPxPM2',
#        'uuid': '28ca699c-cddd-4289-9cf0-25a16881da79',
#        'match': None,
#        'source': 'suggested',
#        'comment': ''}],
#      'suggested': [{'op': '$in',
#        'code': 'REQ_GP_last_exon_not_important',
#        'match': ['LENI'],
#        'source': 'genepanel.last_exon_important'},
#       {'op': '$in',
#        'code': 'REQ_GP_LOF_missense',
#        'match': ['ANY'],
#        'source': 'genepanel.disease_mode'},
#       {'op': '$in',
#        'code': 'REQ_not_in_last_exon',
#        'match': ['no'],
#        'source': 'transcript.in_last_exon'},
#       {'op': '$in',
#        'code': 'REQ_null_variant',
#        'match': ['splice_donor_variant'],
#        'source': 'transcript.consequences'},
#       {'op': '$in',
#        'code': 'REQ_no_freq',
#        'match': ['null_freq'],
#        'source': 'frequencies.commonness'},
#       {'op': None, 'code': 'PVS1', 'match': None, 'source': None},
#       {'op': None, 'code': 'PPxPM2', 'match': None, 'source': None}],
#      'suggested_classification': 4},
#     'external': {'comment': ''},
#     'frequency': {'comment': ''},
#     'reference': {'comment': ''},
#     'prediction': {'comment': ''},
#     'classification': {'comment': ''}},
#    'user_id': 1,
#    'date_created': Timestamp('2020-10-19 07:44:30.335239+0000', tz='psycopg2.tz.FixedOffsetTimezone(offset=0, name=None)'),
#    'date_superceeded': None,
#    'previous_assessment_id': None,
#    'allele_id': 5,
#    'genepanel_name': 'HBOCUTV',
#    'genepanel_version': 'v01',
#    'analysis_id': 2,
#    'annotation_id': 5,
#    'custom_annotation_id': None,
#    'usergroup_id': 1},
#   {'id': 4,
#    'classification': 'U',
#    'evaluation': {'acmg': {'included': [],
#      'suggested': [{'op': '$in',
#        'code': 'REQ_GP_last_exon_not_important',
#        'match': ['LENI'],
#        'source': 'genepanel.last_exon_important'},
#       {'op': '$in',
#        'code': 'REQ_GP_LOF_missense',
#        'match': ['ANY'],
#        'source': 'genepanel.disease_mode'},
#       {'op': '$in',
#        'code': 'REQ_missense',
#        'match': ['missense_variant'],
#        'source': 'transcript.consequences'},
#       {'op': '$in',
#        'code': 'REQ_not_in_last_exon',
#        'match': ['no'],
#        'source': 'transcript.in_last_exon'}],
#      'suggested_classification': None},
#     'external': {'comment': ''},
#     'frequency': {'comment': ''},
#     'reference': {'comment': ''},
#     'prediction': {'comment': ''},
#     'classification': {'comment': ''}},
#    'user_id': 1,
#    'date_created': Timestamp('2020-10-19 07:44:43.334923+0000', tz='psycopg2.tz.FixedOffsetTimezone(offset=0, name=None)'),
#    'date_superceeded': None,
#    'previous_assessment_id': None,
#    'allele_id': 6,
#    'genepanel_name': 'HBOCUTV',
#    'genepanel_version': 'v01',
#    'analysis_id': 2,
#    'annotation_id': 6,
#    'custom_annotation_id': None,
#    'usergroup_id': 1},
#   {'id': 5,
#    'classification': '4',
#    'evaluation': {'acmg': {'included': [{'op': None,
#        'code': 'PVS1',
#        'uuid': '6621c49f-1554-47fe-b6ad-bce4d444791d',
#        'match': None,
#        'source': 'suggested',
#        'comment': ''},
#       {'op': None,
#        'code': 'PPxPM2',
#        'uuid': 'd420c709-1f7f-4f49-8b68-8e918bbd2095',
#        'match': None,
#        'source': 'suggested',
#        'comment': ''}],
#      'suggested': [{'op': '$in',
#        'code': 'REQ_GP_last_exon_not_important',
#        'match': ['LENI'],
#        'source': 'genepanel.last_exon_important'},
#       {'op': '$in',
#        'code': 'REQ_GP_LOF_missense',
#        'match': ['ANY'],
#        'source': 'genepanel.disease_mode'},
#       {'op': '$in',
#        'code': 'REQ_not_in_last_exon',
#        'match': ['no'],
#        'source': 'transcript.in_last_exon'},
#       {'op': '$in',
#        'code': 'REQ_null_variant',
#        'match': ['stop_gained'],
#        'source': 'transcript.consequences'},
#       {'op': '$in',
#        'code': 'REQ_no_freq',
#        'match': ['null_freq'],
#        'source': 'frequencies.commonness'},
#       {'op': None, 'code': 'PVS1', 'match': None, 'source': None},
#       {'op': None, 'code': 'PPxPM2', 'match': None, 'source': None}],
#      'suggested_classification': 4},
#     'external': {'comment': ''},
#     'frequency': {'comment': ''},
#     'reference': {'comment': ''},
#     'prediction': {'comment': ''},
#     'classification': {'comment': ''}},
#    'user_id': 1,
#    'date_created': Timestamp('2020-10-19 07:44:58.945348+0000', tz='psycopg2.tz.FixedOffsetTimezone(offset=0, name=None)'),
#    'date_superceeded': None,
#    'previous_assessment_id': None,
#    'allele_id': 7,
#    'genepanel_name': 'HBOCUTV',
#    'genepanel_version': 'v01',
#    'analysis_id': 2,
#    'annotation_id': 7,
#    'custom_annotation_id': None,
#    'usergroup_id': 1},
#   {'id': 6,
#    'classification': 'U',
#    'evaluation': {'acmg': {'included': [],
#      'suggested': [{'op': '$in',
#        'code': 'REQ_GP_last_exon_not_important',
#        'match': ['LENI'],
#        'source': 'genepanel.last_exon_important'},
#       {'op': '$in',
#        'code': 'REQ_GP_LOF_missense',
#        'match': ['ANY'],
#        'source': 'genepanel.disease_mode'},
#       {'op': '$in',
#        'code': 'REQ_less_common',
#        'match': ['less_common'],
#        'source': 'frequencies.commonness'},
#       {'op': '$in',
#        'code': 'REQ_no_aa_change',
#        'match': ['synonymous_variant'],
#        'source': 'transcript.consequences'},
#       {'op': '$in',
#        'code': 'REQ_not_in_last_exon',
#        'match': ['no'],
#        'source': 'transcript.in_last_exon'}],
#      'suggested_classification': None},
#     'external': {'comment': ''},
#     'frequency': {'comment': ''},
#     'reference': {'comment': ''},
#     'prediction': {'comment': ''},
#     'classification': {'comment': ''}},
#    'user_id': 1,
#    'date_created': Timestamp('2020-10-19 07:45:11.324654+0000', tz='psycopg2.tz.FixedOffsetTimezone(offset=0, name=None)'),
#    'date_superceeded': None,
#    'previous_assessment_id': None,
#    'allele_id': 8,
#    'genepanel_name': 'HBOCUTV',
#    'genepanel_version': 'v01',
#    'analysis_id': 2,
#    'annotation_id': 8,
#    'custom_annotation_id': None,
#    'usergroup_id': 1}],
#  'allele_annotation': [{'id': 3,
#    'allele_id': 3,
#    'annotations': {'external': {'HGMD': {'tag': 'DM',
#       'codon': 4,
#       'acc_num': 'CM082514',
#       'disease': 'Breast and/or ovarian cancer'},
#      'CLINVAR': {'items': [{'rcv': 'SCV000296805',
#         'submitter': 'GeneKor MSA',
#         'traitnames': '',
#         'variant_id': '',
#         'last_evaluated': '01/11/2017',
#         'clinical_significance_descr': 'Pathogenic'},
#        {'rcv': 'SCV000323955',
#         'submitter': 'ENIGMA',
#         'traitnames': '',
#         'variant_id': '',
#         'last_evaluated': '18/10/2016',
#         'clinical_significance_descr': 'Pathogenic'},
#        {'rcv': 'RCV000257718',
#         'submitter': '',
#         'traitnames': 'Breast-ovarian cancer, familial 2',
#         'variant_id': '51063',
#         'last_evaluated': '18/10/2016',
#         'clinical_significance_descr': 'Pathogenic'},
#        {'rcv': 'RCV000239090',
#         'submitter': '',
#         'traitnames': 'not provided',
#         'variant_id': '51063',
#         'last_evaluated': '01/11/2017',
#         'clinical_significance_descr': 'Pathogenic'},
#        {'rcv': 'SCV000326495',
#         'submitter': 'CIMBA',
#         'traitnames': '',
#         'variant_id': '',
#         'last_evaluated': '02/10/2015',
#         'clinical_significance_descr': 'Pathogenic'}],
#       'variant_id': 51063,
#       'variant_description': 'reviewed by expert panel'}},
#     'prediction': {},
#     'references': [{'sources': ['HGMD'],
#       'pubmed_id': 17453335,
#       'source_info': {'HGMD': 'Primary literature report. No comments.'}}],
#     'frequencies': {},
#     'transcripts': [{'dbsnp': ['rs397507571'],
#       'strand': -1,
#       'symbol': 'ZAR1L',
#       'hgnc_id': 37116,
#       'transcript': 'ENST00000345108',
#       'consequences': ['upstream_gene_variant'],
#       'in_last_exon': 'no',
#       'is_canonical': False},
#      {'exon': '2/27',
#       'HGVSc': 'c.10G>T',
#       'HGVSp': 'p.Gly4Ter',
#       'dbsnp': ['rs397507571'],
#       'codons': 'Gga/Tga',
#       'strand': 1,
#       'symbol': 'BRCA2',
#       'hgnc_id': 1101,
#       'protein': 'ENSP00000369497.3',
#       'transcript': 'ENST00000380152',
#       'HGVSc_short': 'c.10G>T',
#       'amino_acids': 'G/*',
#       'consequences': ['stop_gained'],
#       'in_last_exon': 'no',
#       'is_canonical': False,
#       'exon_distance': 0,
#       'coding_region_distance': 0},
#      {'exon': '2/10',
#       'HGVSc': 'c.-356G>T',
#       'dbsnp': ['rs397507571'],
#       'strand': 1,
#       'symbol': 'BRCA2',
#       'hgnc_id': 1101,
#       'transcript': 'ENST00000530893',
#       'HGVSc_short': 'c.-356G>T',
#       'consequences': ['5_prime_UTR_variant'],
#       'in_last_exon': 'no',
#       'is_canonical': False,
#       'exon_distance': 0,
#       'coding_region_distance': -356},
#      {'dbsnp': ['rs397507571'],
#       'strand': -1,
#       'symbol': 'ZAR1L',
#       'hgnc_id': 37116,
#       'transcript': 'ENST00000533490',
#       'consequences': ['upstream_gene_variant'],
#       'in_last_exon': 'no',
#       'is_canonical': True},
#      {'exon': '2/28',
#       'HGVSc': 'c.10G>T',
#       'HGVSp': 'p.Gly4Ter',
#       'dbsnp': ['rs397507571'],
#       'codons': 'Gga/Tga',
#       'strand': 1,
#       'symbol': 'BRCA2',
#       'hgnc_id': 1101,
#       'protein': 'ENSP00000439902.1',
#       'transcript': 'ENST00000544455',
#       'HGVSc_short': 'c.10G>T',
#       'amino_acids': 'G/*',
#       'consequences': ['stop_gained'],
#       'in_last_exon': 'no',
#       'is_canonical': True,
#       'exon_distance': 0,
#       'coding_region_distance': 0},
#      {'exon': '2/27',
#       'HGVSc': 'c.10G>T',
#       'HGVSp': 'p.Gly4Ter',
#       'dbsnp': ['rs397507571'],
#       'codons': 'Gga/Tga',
#       'strand': 1,
#       'symbol': 'BRCA2',
#       'hgnc_id': 1101,
#       'protein': 'NP_000050.2',
#       'transcript': 'NM_000059.3',
#       'HGVSc_short': 'c.10G>T',
#       'amino_acids': 'G/*',
#       'consequences': ['stop_gained'],
#       'in_last_exon': 'no',
#       'is_canonical': True,
#       'exon_distance': 0,
#       'coding_region_distance': 0},
#      {'dbsnp': ['rs397507571'],
#       'strand': -1,
#       'symbol': 'ZAR1L',
#       'hgnc_id': 37116,
#       'transcript': 'NM_001136571.1',
#       'consequences': ['upstream_gene_variant'],
#       'in_last_exon': 'no',
#       'is_canonical': True}]},
#    'previous_annotation_id': None,
#    'date_superceeded': None,
#    'date_created': Timestamp('2020-10-19 07:29:46.327638+0000', tz='UTC'),
#    'schema_version': 1},
#   {'id': 4,
#    'allele_id': 4,
#    'annotations': {'external': {'HGMD': {'tag': 'DM',
#       'codon': 16,
#       'acc_num': 'CD961847',
#       'disease': 'Breast cancer'},
#      'CLINVAR': {'items': [{'rcv': 'RCV000131871',
#         'submitter': '',
#         'traitnames': 'Hereditary cancer-predisposing syndrome',
#         'variant_id': '51814',
#         'last_evaluated': '12/12/2016',
#         'clinical_significance_descr': 'Pathogenic'},
#        {'rcv': 'SCV000279262',
#         'submitter': 'GeneDx',
#         'traitnames': 'Not Provided',
#         'variant_id': '',
#         'last_evaluated': '21/01/2016',
#         'clinical_significance_descr': 'Pathogenic'},
#        {'rcv': 'SCV000282398',
#         'submitter': 'ENIGMA',
#         'traitnames': '',
#         'variant_id': '',
#         'last_evaluated': '22/04/2016',
#         'clinical_significance_descr': 'Pathogenic'},
#        {'rcv': 'RCV000113063',
#         'submitter': '',
#         'traitnames': 'Breast-ovarian cancer, familial 2',
#         'variant_id': '51814',
#         'last_evaluated': '22/04/2016',
#         'clinical_significance_descr': 'Pathogenic'},
#        {'rcv': 'SCV000694829',
#         'submitter': 'Integrated Genetics/Laboratory Corporation of America',
#         'traitnames': '',
#         'variant_id': '',
#         'last_evaluated': '06/01/2016',
#         'clinical_significance_descr': 'Pathogenic'},
#        {'rcv': 'SCV000327129',
#         'submitter': 'CIMBA',
#         'traitnames': '',
#         'variant_id': '',
#         'last_evaluated': '02/10/2015',
#         'clinical_significance_descr': 'Pathogenic'},
#        {'rcv': 'SCV000186926',
#         'submitter': 'Ambry Genetics',
#         'traitnames': 'Hereditary cancer-predisposing syndrome',
#         'variant_id': '',
#         'last_evaluated': '23/09/2016',
#         'clinical_significance_descr': 'Pathogenic'},
#        {'rcv': 'SCV000146071',
#         'submitter': 'BIC (BRCA2)',
#         'traitnames': 'Breast-ovarian cancer, familial 2',
#         'variant_id': '',
#         'last_evaluated': '29/05/2002',
#         'clinical_significance_descr': 'Pathogenic'},
#        {'rcv': 'RCV000219019',
#         'submitter': '',
#         'traitnames': 'not provided',
#         'variant_id': '51814',
#         'last_evaluated': '21/01/2016',
#         'clinical_significance_descr': 'Pathogenic'},
#        {'rcv': 'SCV000683670',
#         'submitter': 'Color Genomics, Inc.',
#         'traitnames': '',
#         'variant_id': '',
#         'last_evaluated': '12/12/2016',
#         'clinical_significance_descr': 'Pathogenic'},
#        {'rcv': 'SCV000591655',
#         'submitter': 'Department of Pathology and Laboratory Medicine,Sinai Health System',
#         'traitnames': '',
#         'variant_id': '',
#         'last_evaluated': '17/02/2015',
#         'clinical_significance_descr': 'Pathogenic'},
#        {'rcv': 'SCV000587530',
#         'submitter': "Research Molecular Genetics Laboratory,Women's College Hospital, University of Toronto",
#         'traitnames': '',
#         'variant_id': '',
#         'last_evaluated': '31/01/2014',
#         'clinical_significance_descr': 'Pathogenic'},
#        {'rcv': 'RCV000496563',
#         'submitter': '',
#         'traitnames': 'Hereditary breast and ovarian cancer syndrome',
#         'variant_id': '51814',
#         'last_evaluated': '06/01/2016',
#         'clinical_significance_descr': 'Pathogenic'},
#        {'rcv': 'RCV000044604',
#         'submitter': '',
#         'traitnames': 'Familial cancer of breast',
#         'variant_id': '51814',
#         'last_evaluated': '01/07/2016',
#         'clinical_significance_descr': 'Pathogenic'},
#        {'rcv': 'SCV000296839',
#         'submitter': 'GeneKor MSA',
#         'traitnames': '',
#         'variant_id': '',
#         'last_evaluated': '01/07/2016',
#         'clinical_significance_descr': 'Pathogenic'}],
#       'variant_id': 51814,
#       'variant_description': 'reviewed by expert panel'}},
#     'prediction': {},
#     'references': [{'sources': ['HGMD', 'CLINVAR'],
#       'pubmed_id': 8589730,
#       'source_info': {'HGMD': 'Primary literature report. aka 279delAC.'}},
#      {'sources': ['HGMD', 'CLINVAR'],
#       'pubmed_id': 18607349,
#       'source_info': {'HGMD': 'Functional characterisation. No comments.'}},
#      {'sources': ['HGMD'],
#       'pubmed_id': 28324225,
#       'source_info': {'HGMD': 'Additional phenotype. Breast and/or ovarian cancer.'}},
#      {'sources': ['CLINVAR'], 'pubmed_id': 18092194, 'source_info': {}},
#      {'sources': ['CLINVAR'], 'pubmed_id': 9245992, 'source_info': {}},
#      {'sources': ['CLINVAR'], 'pubmed_id': 10070953, 'source_info': {}},
#      {'sources': ['CLINVAR'], 'pubmed_id': 22430266, 'source_info': {}},
#      {'sources': ['CLINVAR'], 'pubmed_id': 20927582, 'source_info': {}}],
#     'frequencies': {},
#     'transcripts': [{'strand': -1,
#       'symbol': 'ZAR1L',
#       'hgnc_id': 37116,
#       'transcript': 'ENST00000345108',
#       'consequences': ['upstream_gene_variant'],
#       'in_last_exon': 'no',
#       'is_canonical': False},
#      {'exon': '2/27',
#       'HGVSc': 'c.51_52delAC',
#       'HGVSp': 'p.Arg18LeufsTer12',
#       'codons': 'ACa/a',
#       'strand': 1,
#       'symbol': 'BRCA2',
#       'hgnc_id': 1101,
#       'protein': 'ENSP00000369497.3',
#       'transcript': 'ENST00000380152',
#       'HGVSc_short': 'c.51_52delAC',
#       'amino_acids': 'T/X',
#       'consequences': ['frameshift_variant'],
#       'in_last_exon': 'no',
#       'is_canonical': False,
#       'exon_distance': 0,
#       'coding_region_distance': 0},
#      {'exon': '2/10',
#       'HGVSc': 'c.-315_-314delAC',
#       'strand': 1,
#       'symbol': 'BRCA2',
#       'hgnc_id': 1101,
#       'transcript': 'ENST00000530893',
#       'HGVSc_short': 'c.-315_-314delAC',
#       'consequences': ['5_prime_UTR_variant'],
#       'in_last_exon': 'no',
#       'is_canonical': False,
#       'exon_distance': 0,
#       'coding_region_distance': -314},
#      {'strand': -1,
#       'symbol': 'ZAR1L',
#       'hgnc_id': 37116,
#       'transcript': 'ENST00000533490',
#       'consequences': ['upstream_gene_variant'],
#       'in_last_exon': 'no',
#       'is_canonical': True},
#      {'exon': '2/28',
#       'HGVSc': 'c.51_52delAC',
#       'HGVSp': 'p.Arg18LeufsTer12',
#       'codons': 'ACa/a',
#       'strand': 1,
#       'symbol': 'BRCA2',
#       'hgnc_id': 1101,
#       'protein': 'ENSP00000439902.1',
#       'transcript': 'ENST00000544455',
#       'HGVSc_short': 'c.51_52delAC',
#       'amino_acids': 'T/X',
#       'consequences': ['frameshift_variant'],
#       'in_last_exon': 'no',
#       'is_canonical': True,
#       'exon_distance': 0,
#       'coding_region_distance': 0},
#      {'exon': '2/27',
#       'HGVSc': 'c.51_52delAC',
#       'HGVSp': 'p.Arg18LeufsTer12',
#       'codons': 'ACa/a',
#       'strand': 1,
#       'symbol': 'BRCA2',
#       'hgnc_id': 1101,
#       'protein': 'NP_000050.2',
#       'transcript': 'NM_000059.3',
#       'HGVSc_short': 'c.51_52delAC',
#       'amino_acids': 'T/X',
#       'consequences': ['frameshift_variant'],
#       'in_last_exon': 'no',
#       'is_canonical': True,
#       'exon_distance': 0,
#       'coding_region_distance': 0},
#      {'strand': -1,
#       'symbol': 'ZAR1L',
#       'hgnc_id': 37116,
#       'transcript': 'NM_001136571.1',
#       'consequences': ['upstream_gene_variant'],
#       'in_last_exon': 'no',
#       'is_canonical': True}]},
#    'previous_annotation_id': None,
#    'date_superceeded': None,
#    'date_created': Timestamp('2020-10-19 07:29:46.327657+0000', tz='UTC'),
#    'schema_version': 1},
#   {'id': 5,
#    'allele_id': 5,
#    'annotations': {'external': {'HGMD': {'tag': 'DM',
#       'acc_num': 'CS087186',
#       'disease': 'Breast cancer'},
#      'CLINVAR': {'items': [{'rcv': 'RCV000113080',
#         'submitter': '',
#         'traitnames': 'Breast-ovarian cancer, familial 2',
#         'variant_id': '52162',
#         'last_evaluated': '24/02/2003',
#         'clinical_significance_descr': 'Pathogenic'},
#        {'rcv': 'SCV000146095',
#         'submitter': 'BIC (BRCA2)',
#         'traitnames': 'Breast-ovarian cancer, familial 2',
#         'variant_id': '',
#         'last_evaluated': '24/02/2003',
#         'clinical_significance_descr': 'Pathogenic'}],
#       'variant_id': 52162,
#       'variant_description': 'no assertion criteria provided'}},
#     'prediction': {},
#     'references': [{'sources': ['HGMD'],
#       'pubmed_id': 18092194,
#       'source_info': {'HGMD': 'Primary literature report. Descr. in Suppl. Table 1 (online).'}},
#      {'sources': ['HGMD'],
#       'pubmed_id': 25525159,
#       'source_info': {'HGMD': 'Additional report. predicted to induce a large splicing change - Table S4.'}}],
#     'frequencies': {},
#     'transcripts': [{'dbsnp': ['rs81002885'],
#       'strand': -1,
#       'symbol': 'ZAR1L',
#       'hgnc_id': 37116,
#       'transcript': 'ENST00000345108',
#       'consequences': ['upstream_gene_variant'],
#       'in_last_exon': 'no',
#       'is_canonical': False},
#      {'HGVSc': 'c.67+2T>A',
#       'dbsnp': ['rs81002885'],
#       'intron': '2/26',
#       'strand': 1,
#       'symbol': 'BRCA2',
#       'hgnc_id': 1101,
#       'transcript': 'ENST00000380152',
#       'HGVSc_short': 'c.67+2T>A',
#       'consequences': ['splice_donor_variant'],
#       'in_last_exon': 'no',
#       'is_canonical': False,
#       'exon_distance': 2,
#       'coding_region_distance': None},
#      {'HGVSc': 'c.-303+6T>A',
#       'dbsnp': ['rs81002885'],
#       'intron': '2/9',
#       'strand': 1,
#       'symbol': 'BRCA2',
#       'hgnc_id': 1101,
#       'transcript': 'ENST00000530893',
#       'HGVSc_short': 'c.-303+6T>A',
#       'consequences': ['intron_variant', 'splice_region_variant'],
#       'in_last_exon': 'no',
#       'is_canonical': False,
#       'exon_distance': 6,
#       'coding_region_distance': None},
#      {'dbsnp': ['rs81002885'],
#       'strand': -1,
#       'symbol': 'ZAR1L',
#       'hgnc_id': 37116,
#       'transcript': 'ENST00000533490',
#       'consequences': ['upstream_gene_variant'],
#       'in_last_exon': 'no',
#       'is_canonical': True},
#      {'HGVSc': 'c.67+2T>A',
#       'dbsnp': ['rs81002885'],
#       'intron': '2/27',
#       'strand': 1,
#       'symbol': 'BRCA2',
#       'hgnc_id': 1101,
#       'transcript': 'ENST00000544455',
#       'HGVSc_short': 'c.67+2T>A',
#       'consequences': ['splice_donor_variant'],
#       'in_last_exon': 'no',
#       'is_canonical': True,
#       'exon_distance': 2,
#       'coding_region_distance': None},
#      {'HGVSc': 'c.67+2T>A',
#       'dbsnp': ['rs81002885'],
#       'intron': '2/26',
#       'strand': 1,
#       'symbol': 'BRCA2',
#       'hgnc_id': 1101,
#       'transcript': 'NM_000059.3',
#       'HGVSc_short': 'c.67+2T>A',
#       'consequences': ['splice_donor_variant'],
#       'in_last_exon': 'no',
#       'is_canonical': True,
#       'exon_distance': 2,
#       'coding_region_distance': None},
#      {'dbsnp': ['rs81002885'],
#       'strand': -1,
#       'symbol': 'ZAR1L',
#       'hgnc_id': 37116,
#       'transcript': 'NM_001136571.1',
#       'consequences': ['upstream_gene_variant'],
#       'in_last_exon': 'no',
#       'is_canonical': True}]},
#    'previous_annotation_id': None,
#    'date_superceeded': None,
#    'date_created': Timestamp('2020-10-19 07:29:46.327665+0000', tz='UTC'),
#    'schema_version': 1},
#   {'id': 6,
#    'allele_id': 6,
#    'annotations': {'external': {'HGMD': {'tag': 'DM',
#       'codon': 24,
#       'acc_num': 'CM111973',
#       'disease': 'Breast and/or ovarian cancer'},
#      'CLINVAR': {'items': [{'rcv': 'SCV000678953',
#         'submitter': 'ClinVar Staff, National Center for Biotechnology Information (NCBI)',
#         'traitnames': 'Familial cancer of breast',
#         'variant_id': '',
#         'last_evaluated': '',
#         'clinical_significance_descr': 'not provided'},
#        {'rcv': 'RCV000577171',
#         'submitter': '',
#         'traitnames': 'Familial cancer of breast',
#         'variant_id': '52303',
#         'last_evaluated': '',
#         'clinical_significance_descr': 'not provided'}],
#       'variant_id': 52303,
#       'variant_description': 'no assertion criteria provided'}},
#     'prediction': {},
#     'references': [{'sources': ['HGMD', 'CLINVAR'],
#       'pubmed_id': 21356067,
#       'source_info': {'HGMD': 'Primary literature report. No comments.'}},
#      {'sources': ['HGMD'],
#       'pubmed_id': 25525159,
#       'source_info': {'HGMD': 'Additional report. predicted to induce a large splicing change - Table S4.'}}],
#     'frequencies': {'ExAC': {'hom': {'G': 0,
#        'AFR': 0,
#        'AMR': 0,
#        'EAS': 0,
#        'FIN': 0,
#        'NFE': 0,
#        'OTH': 0,
#        'SAS': 0},
#       'num': {'G': 119160,
#        'AFR': 9500,
#        'AMR': 11530,
#        'EAS': 8550,
#        'FIN': 6600,
#        'NFE': 65594,
#        'OTH': 894,
#        'SAS': 16492},
#       'freq': {'G': 1.6784155756965425e-05,
#        'AFR': 0.0,
#        'AMR': 0.0,
#        'EAS': 0.0,
#        'FIN': 0.00030303030303030303,
#        'NFE': 0.0,
#        'OTH': 0.0,
#        'SAS': 0.0},
#       'count': {'G': 2,
#        'AFR': 0,
#        'AMR': 0,
#        'EAS': 0,
#        'FIN': 2,
#        'Het': 2,
#        'NFE': 0,
#        'OTH': 0,
#        'SAS': 0}},
#      'GNOMAD_EXOMES': {'hom': {'G': 0,
#        'AFR': 0,
#        'AMR': 0,
#        'ASJ': 0,
#        'EAS': 0,
#        'FIN': 0,
#        'NFE': 0,
#        'OTH': 0,
#        'SAS': 0,
#        'Male': 0,
#        'Female': 0},
#       'num': {'G': 245534,
#        'AFR': 15200,
#        'AMR': 33558,
#        'ASJ': 9828,
#        'EAS': 17220,
#        'FIN': 22286,
#        'NFE': 111296,
#        'OTH': 5474,
#        'SAS': 30672,
#        'Male': 134558,
#        'Female': 110976},
#       'freq': {'G': 2.0363778539835625e-05,
#        'AFR': 0.0,
#        'AMR': 0.0,
#        'ASJ': 0.0,
#        'EAS': 0.0,
#        'FIN': 0.0002243560979987436,
#        'NFE': 0.0,
#        'OTH': 0.0,
#        'SAS': 0.0,
#        'Male': 7.431739472941036e-06,
#        'Female': 3.604382929642445e-05},
#       'count': {'G': 5,
#        'AFR': 0,
#        'AMR': 0,
#        'ASJ': 0,
#        'EAS': 0,
#        'FIN': 5,
#        'NFE': 0,
#        'OTH': 0,
#        'SAS': 0,
#        'Male': 1,
#        'Female': 4},
#       'filter': {'G': ['PASS']}}},
#     'transcripts': [{'exon': '3/27',
#       'HGVSc': 'c.72A>T',
#       'HGVSp': 'p.Leu24Phe',
#       'dbsnp': ['rs397507909'],
#       'codons': 'ttA/ttT',
#       'strand': 1,
#       'symbol': 'BRCA2',
#       'hgnc_id': 1101,
#       'protein': 'ENSP00000369497.3',
#       'transcript': 'ENST00000380152',
#       'HGVSc_short': 'c.72A>T',
#       'amino_acids': 'L/F',
#       'consequences': ['missense_variant'],
#       'in_last_exon': 'no',
#       'is_canonical': False,
#       'exon_distance': 0,
#       'coding_region_distance': 0},
#      {'exon': '3/10',
#       'HGVSc': 'c.-298A>T',
#       'dbsnp': ['rs397507909'],
#       'strand': 1,
#       'symbol': 'BRCA2',
#       'hgnc_id': 1101,
#       'transcript': 'ENST00000530893',
#       'HGVSc_short': 'c.-298A>T',
#       'consequences': ['5_prime_UTR_variant'],
#       'in_last_exon': 'no',
#       'is_canonical': False,
#       'exon_distance': 0,
#       'coding_region_distance': -298},
#      {'dbsnp': ['rs397507909'],
#       'strand': -1,
#       'symbol': 'ZAR1L',
#       'hgnc_id': 37116,
#       'transcript': 'ENST00000533490',
#       'consequences': ['upstream_gene_variant'],
#       'in_last_exon': 'no',
#       'is_canonical': True},
#      {'exon': '3/28',
#       'HGVSc': 'c.72A>T',
#       'HGVSp': 'p.Leu24Phe',
#       'dbsnp': ['rs397507909'],
#       'codons': 'ttA/ttT',
#       'strand': 1,
#       'symbol': 'BRCA2',
#       'hgnc_id': 1101,
#       'protein': 'ENSP00000439902.1',
#       'transcript': 'ENST00000544455',
#       'HGVSc_short': 'c.72A>T',
#       'amino_acids': 'L/F',
#       'consequences': ['missense_variant'],
#       'in_last_exon': 'no',
#       'is_canonical': True,
#       'exon_distance': 0,
#       'coding_region_distance': 0},
#      {'exon': '3/27',
#       'HGVSc': 'c.72A>T',
#       'HGVSp': 'p.Leu24Phe',
#       'dbsnp': ['rs397507909'],
#       'codons': 'ttA/ttT',
#       'strand': 1,
#       'symbol': 'BRCA2',
#       'hgnc_id': 1101,
#       'protein': 'NP_000050.2',
#       'transcript': 'NM_000059.3',
#       'HGVSc_short': 'c.72A>T',
#       'amino_acids': 'L/F',
#       'consequences': ['missense_variant'],
#       'in_last_exon': 'no',
#       'is_canonical': True,
#       'exon_distance': 0,
#       'coding_region_distance': 0}]},
#    'previous_annotation_id': None,
#    'date_superceeded': None,
#    'date_created': Timestamp('2020-10-19 07:29:46.327672+0000', tz='UTC'),
#    'schema_version': 1},
#   {'id': 7,
#    'allele_id': 7,
#    'annotations': {'external': {'HGMD': {'tag': 'DM',
#       'codon': 33,
#       'acc_num': 'CM067653',
#       'disease': 'Breast and/or ovarian cancer'},
#      'CLINVAR': {'items': [{'rcv': 'SCV000324794',
#         'submitter': 'ENIGMA',
#         'traitnames': '',
#         'variant_id': '',
#         'last_evaluated': '18/10/2016',
#         'clinical_significance_descr': 'Pathogenic'},
#        {'rcv': 'RCV000256555',
#         'submitter': '',
#         'traitnames': 'Breast-ovarian cancer, familial 2',
#         'variant_id': '52900',
#         'last_evaluated': '18/10/2016',
#         'clinical_significance_descr': 'Pathogenic'},
#        {'rcv': 'SCV000328170',
#         'submitter': 'CIMBA',
#         'traitnames': '',
#         'variant_id': '',
#         'last_evaluated': '02/10/2015',
#         'clinical_significance_descr': 'Pathogenic'}],
#       'variant_id': 52900,
#       'variant_description': 'reviewed by expert panel'}},
#     'prediction': {},
#     'references': [{'sources': ['HGMD'],
#       'pubmed_id': 16760289,
#       'source_info': {'HGMD': 'Primary literature report. No comments.'}},
#      {'sources': ['HGMD'],
#       'pubmed_id': 16847550,
#       'source_info': {'HGMD': 'Additional report. No comments.'}},
#      {'sources': ['HGMD'],
#       'pubmed_id': 25525159,
#       'source_info': {'HGMD': 'Additional report. predicted to induce a large splicing change - Table S4.'}}],
#     'frequencies': {},
#     'transcripts': [{'exon': '3/27',
#       'HGVSc': 'c.97G>T',
#       'HGVSp': 'p.Glu33Ter',
#       'dbsnp': ['rs397508065'],
#       'codons': 'Gaa/Taa',
#       'strand': 1,
#       'symbol': 'BRCA2',
#       'hgnc_id': 1101,
#       'protein': 'ENSP00000369497.3',
#       'transcript': 'ENST00000380152',
#       'HGVSc_short': 'c.97G>T',
#       'amino_acids': 'E/*',
#       'consequences': ['stop_gained'],
#       'in_last_exon': 'no',
#       'is_canonical': False,
#       'exon_distance': 0,
#       'coding_region_distance': 0},
#      {'exon': '3/10',
#       'HGVSc': 'c.-273G>T',
#       'dbsnp': ['rs397508065'],
#       'strand': 1,
#       'symbol': 'BRCA2',
#       'hgnc_id': 1101,
#       'transcript': 'ENST00000530893',
#       'HGVSc_short': 'c.-273G>T',
#       'consequences': ['5_prime_UTR_variant'],
#       'in_last_exon': 'no',
#       'is_canonical': False,
#       'exon_distance': 0,
#       'coding_region_distance': -273},
#      {'dbsnp': ['rs397508065'],
#       'strand': -1,
#       'symbol': 'ZAR1L',
#       'hgnc_id': 37116,
#       'transcript': 'ENST00000533490',
#       'consequences': ['upstream_gene_variant'],
#       'in_last_exon': 'no',
#       'is_canonical': True},
#      {'exon': '3/28',
#       'HGVSc': 'c.97G>T',
#       'HGVSp': 'p.Glu33Ter',
#       'dbsnp': ['rs397508065'],
#       'codons': 'Gaa/Taa',
#       'strand': 1,
#       'symbol': 'BRCA2',
#       'hgnc_id': 1101,
#       'protein': 'ENSP00000439902.1',
#       'transcript': 'ENST00000544455',
#       'HGVSc_short': 'c.97G>T',
#       'amino_acids': 'E/*',
#       'consequences': ['stop_gained'],
#       'in_last_exon': 'no',
#       'is_canonical': True,
#       'exon_distance': 0,
#       'coding_region_distance': 0},
#      {'exon': '3/27',
#       'HGVSc': 'c.97G>T',
#       'HGVSp': 'p.Glu33Ter',
#       'dbsnp': ['rs397508065'],
#       'codons': 'Gaa/Taa',
#       'strand': 1,
#       'symbol': 'BRCA2',
#       'hgnc_id': 1101,
#       'protein': 'NP_000050.2',
#       'transcript': 'NM_000059.3',
#       'HGVSc_short': 'c.97G>T',
#       'amino_acids': 'E/*',
#       'consequences': ['stop_gained'],
#       'in_last_exon': 'no',
#       'is_canonical': True,
#       'exon_distance': 0,
#       'coding_region_distance': 0}]},
#    'previous_annotation_id': None,
#    'date_superceeded': None,
#    'date_created': Timestamp('2020-10-19 07:29:46.327678+0000', tz='UTC'),
#    'schema_version': 1},
#   {'id': 8,
#    'allele_id': 8,
#    'annotations': {'external': {'HGMD': {'tag': 'DM?',
#       'codon': 66,
#       'acc_num': 'CM173583',
#       'disease': 'Breast and/or ovarian cancer'},
#      'CLINVAR': {'items': [{'rcv': 'RCV000377649',
#         'submitter': '',
#         'traitnames': 'Fanconi anemia',
#         'variant_id': '51234',
#         'last_evaluated': '14/06/2016',
#         'clinical_significance_descr': 'Likely benign'},
#        {'rcv': 'RCV000162901',
#         'submitter': '',
#         'traitnames': 'Hereditary cancer-predisposing syndrome',
#         'variant_id': '51234',
#         'last_evaluated': '02/04/2015',
#         'clinical_significance_descr': 'Likely benign'},
#        {'rcv': 'SCV000383604',
#         'submitter': 'Illumina',
#         'traitnames': 'Hereditary Breast and Ovarian Cancer',
#         'variant_id': '',
#         'last_evaluated': '14/06/2016',
#         'clinical_significance_descr': 'Likely benign'},
#        {'rcv': 'SCV000578005',
#         'submitter': 'ENIGMA',
#         'traitnames': '',
#         'variant_id': '',
#         'last_evaluated': '29/06/2017',
#         'clinical_significance_descr': 'Benign'},
#        {'rcv': 'RCV000499809',
#         'submitter': '',
#         'traitnames': 'not specified',
#         'variant_id': '51234',
#         'last_evaluated': '15/11/2012',
#         'clinical_significance_descr': 'Benign'},
#        {'rcv': 'SCV000213388',
#         'submitter': 'Ambry Genetics',
#         'traitnames': 'Hereditary cancer-predisposing syndrome',
#         'variant_id': '',
#         'last_evaluated': '04/07/2014',
#         'clinical_significance_descr': 'Likely benign'},
#        {'rcv': 'RCV000113265',
#         'submitter': '',
#         'traitnames': 'Breast-ovarian cancer, familial 2',
#         'variant_id': '51234',
#         'last_evaluated': '29/06/2017',
#         'clinical_significance_descr': 'Benign'},
#        {'rcv': 'SCV000071946',
#         'submitter': 'Invitae',
#         'traitnames': '',
#         'variant_id': '',
#         'last_evaluated': '03/01/2018',
#         'clinical_significance_descr': 'Benign'},
#        {'rcv': 'SCV000146362',
#         'submitter': 'BIC (BRCA2)',
#         'traitnames': 'Breast-ovarian cancer, familial 2',
#         'variant_id': '',
#         'last_evaluated': '18/09/2010',
#         'clinical_significance_descr': 'Benign'},
#        {'rcv': 'SCV000591663',
#         'submitter': 'Department of Pathology and Laboratory Medicine,Sinai Health System',
#         'traitnames': 'not specified',
#         'variant_id': '',
#         'last_evaluated': '15/11/2012',
#         'clinical_significance_descr': 'Benign'},
#        {'rcv': 'SCV000383605',
#         'submitter': 'Illumina',
#         'traitnames': 'Fanconi Anemia',
#         'variant_id': '',
#         'last_evaluated': '14/06/2016',
#         'clinical_significance_descr': 'Likely benign'},
#        {'rcv': 'RCV000167850',
#         'submitter': '',
#         'traitnames': 'Hereditary breast and ovarian cancer syndrome',
#         'variant_id': '51234',
#         'last_evaluated': '03/01/2018',
#         'clinical_significance_descr': 'Benign/Likely benign'},
#        {'rcv': 'SCV000683467',
#         'submitter': 'Color Genomics, Inc.',
#         'traitnames': '',
#         'variant_id': '',
#         'last_evaluated': '02/04/2015',
#         'clinical_significance_descr': 'Likely benign'}],
#       'variant_id': 51234,
#       'variant_description': 'reviewed by expert panel'}},
#     'prediction': {},
#     'references': [{'sources': ['HGMD'],
#       'pubmed_id': 28324225,
#       'source_info': {'HGMD': 'Primary literature report. Classified as VUS3 (IARC).'}},
#      {'sources': ['CLINVAR'], 'pubmed_id': 18844490, 'source_info': {}},
#      {'sources': ['CLINVAR'], 'pubmed_id': 28492532, 'source_info': {}},
#      {'sources': ['CLINVAR'], 'pubmed_id': 19471317, 'source_info': {}},
#      {'sources': ['CLINVAR'], 'pubmed_id': 10923033, 'source_info': {}}],
#     'frequencies': {'ExAC': {'hom': {'G': 3,
#        'AFR': 0,
#        'AMR': 0,
#        'EAS': 0,
#        'FIN': 0,
#        'NFE': 0,
#        'OTH': 0,
#        'SAS': 3},
#       'num': {'G': 121222,
#        'AFR': 10322,
#        'AMR': 11568,
#        'EAS': 8652,
#        'FIN': 6614,
#        'NFE': 66654,
#        'OTH': 906,
#        'SAS': 16506},
#       'freq': {'G': 0.0010724125983732325,
#        'AFR': 0.0,
#        'AMR': 8.644536652835408e-05,
#        'EAS': 0.0,
#        'FIN': 0.0,
#        'NFE': 0.00019503705704083775,
#        'OTH': 0.0,
#        'SAS': 0.007027747485762753},
#       'count': {'G': 130,
#        'AFR': 0,
#        'AMR': 1,
#        'EAS': 0,
#        'FIN': 0,
#        'Het': 124,
#        'NFE': 13,
#        'OTH': 0,
#        'SAS': 116}},
#      'inDB': {'hom': {'OUST1': 0},
#       'num': {'OUST1': 588},
#       'freq': {'OUST1': 0.0017006802721088435},
#       'count': {'OUST1': 1},
#       'filter': {'OUST1': ['PASS']},
#       'indications': {'OUST1': {'TrioPU': '1'}}},
#      '1000g': {'freq': {'G': 0.002,
#        'AFR': 0.0,
#        'AMR': 0.0,
#        'EAS': 0.0,
#        'EUR': 0.001,
#        'SAS': 0.0092}},
#      'esp6500': {'freq': {'AA': 0.0, 'EA': 0.0003}},
#      'GNOMAD_EXOMES': {'hom': {'G': 5,
#        'AFR': 0,
#        'AMR': 0,
#        'ASJ': 0,
#        'EAS': 0,
#        'FIN': 0,
#        'NFE': 0,
#        'OTH': 0,
#        'SAS': 5,
#        'Male': 2,
#        'Female': 3},
#       'num': {'G': 246204,
#        'AFR': 15296,
#        'AMR': 33580,
#        'ASJ': 9848,
#        'EAS': 17246,
#        'FIN': 22296,
#        'NFE': 111674,
#        'OTH': 5484,
#        'SAS': 30780,
#        'Male': 134874,
#        'Female': 111330},
#       'freq': {'G': 0.001108836574547936,
#        'AFR': 0.0,
#        'AMR': 8.933889219773674e-05,
#        'ASJ': 0.0,
#        'EAS': 0.0,
#        'FIN': 0.0,
#        'NFE': 0.00026863907444884215,
#        'OTH': 0.0005470459518599562,
#        'SAS': 0.007699805068226121,
#        'Male': 0.0014828654892714683,
#        'Female': 0.0006557082547381659},
#       'count': {'G': 273,
#        'AFR': 0,
#        'AMR': 3,
#        'ASJ': 0,
#        'EAS': 0,
#        'FIN': 0,
#        'NFE': 30,
#        'OTH': 3,
#        'SAS': 237,
#        'Male': 200,
#        'Female': 73},
#       'filter': {'G': ['PASS']}},
#      'GNOMAD_GENOMES': {'hom': {'G': 0,
#        'AFR': 0,
#        'AMR': 0,
#        'ASJ': 0,
#        'EAS': 0,
#        'FIN': 0,
#        'NFE': 0,
#        'OTH': 0,
#        'Male': 0,
#        'Female': 0},
#       'num': {'G': 30980,
#        'AFR': 8736,
#        'AMR': 838,
#        'ASJ': 302,
#        'EAS': 1622,
#        'FIN': 3494,
#        'NFE': 15008,
#        'OTH': 980,
#        'Male': 17122,
#        'Female': 13858},
#       'freq': {'G': 0.0001291155584247902,
#        'AFR': 0.0,
#        'AMR': 0.0,
#        'ASJ': 0.0,
#        'EAS': 0.0,
#        'FIN': 0.0,
#        'NFE': 0.00026652452025586353,
#        'OTH': 0.0,
#        'Male': 0.00011680878402055835,
#        'Female': 0.0001443209698369173},
#       'count': {'G': 4,
#        'AFR': 0,
#        'AMR': 0,
#        'ASJ': 0,
#        'EAS': 0,
#        'FIN': 0,
#        'NFE': 4,
#        'OTH': 0,
#        'Male': 2,
#        'Female': 2},
#       'filter': {'G': ['PASS']}}},
#     'transcripts': [{'exon': '3/27',
#       'HGVSc': 'c.198A>G',
#       'HGVSp': 'c.198A>G(p.=)',
#       'dbsnp': ['rs28897700'],
#       'codons': 'caA/caG',
#       'strand': 1,
#       'symbol': 'BRCA2',
#       'hgnc_id': 1101,
#       'protein': 'ENST00000380152.3',
#       'transcript': 'ENST00000380152',
#       'HGVSc_short': 'c.198A>G',
#       'amino_acids': 'Q',
#       'consequences': ['synonymous_variant'],
#       'in_last_exon': 'no',
#       'is_canonical': False,
#       'exon_distance': 0,
#       'coding_region_distance': 0},
#      {'exon': '3/10',
#       'HGVSc': 'c.-172A>G',
#       'dbsnp': ['rs28897700'],
#       'strand': 1,
#       'symbol': 'BRCA2',
#       'hgnc_id': 1101,
#       'transcript': 'ENST00000530893',
#       'HGVSc_short': 'c.-172A>G',
#       'consequences': ['5_prime_UTR_variant'],
#       'in_last_exon': 'no',
#       'is_canonical': False,
#       'exon_distance': 0,
#       'coding_region_distance': -172},
#      {'dbsnp': ['rs28897700'],
#       'strand': -1,
#       'symbol': 'ZAR1L',
#       'hgnc_id': 37116,
#       'transcript': 'ENST00000533490',
#       'consequences': ['upstream_gene_variant'],
#       'in_last_exon': 'no',
#       'is_canonical': True},
#      {'exon': '3/28',
#       'HGVSc': 'c.198A>G',
#       'HGVSp': 'c.198A>G(p.=)',
#       'dbsnp': ['rs28897700'],
#       'codons': 'caA/caG',
#       'strand': 1,
#       'symbol': 'BRCA2',
#       'hgnc_id': 1101,
#       'protein': 'ENST00000544455.1',
#       'transcript': 'ENST00000544455',
#       'HGVSc_short': 'c.198A>G',
#       'amino_acids': 'Q',
#       'consequences': ['synonymous_variant'],
#       'in_last_exon': 'no',
#       'is_canonical': True,
#       'exon_distance': 0,
#       'coding_region_distance': 0},
#      {'exon': '3/27',
#       'HGVSc': 'c.198A>G',
#       'HGVSp': 'c.198A>G(p.=)',
#       'dbsnp': ['rs28897700'],
#       'codons': 'caA/caG',
#       'strand': 1,
#       'symbol': 'BRCA2',
#       'hgnc_id': 1101,
#       'protein': 'NM_000059.3',
#       'transcript': 'NM_000059.3',
#       'HGVSc_short': 'c.198A>G',
#       'amino_acids': 'Q',
#       'consequences': ['synonymous_variant'],
#       'in_last_exon': 'no',
#       'is_canonical': True,
#       'exon_distance': 0,
#       'coding_region_distance': 0}]},
#    'previous_annotation_id': None,
#    'date_superceeded': None,
#    'date_created': Timestamp('2020-10-19 07:29:46.327685+0000', tz='UTC'),
#    'schema_version': 1}]}
