# %% [markdown]
# # Generate Report From the ELLA REST API
#
# Let's load in the data we fetched from `Creating-Custom-Reports/Parse-Analysis-From-REST-API.ipynb`.

# %%
import json
import pandas as pd
import os
import copy
from pprint import pprint

## All data will be loaded in asyncronously from REST APIs

with open('/data/analysis_rest_api_data.json', 'r') as reader:
    analysis_data = json.load(reader)

with open('/data/mock_patient_data.json', 'r') as reader:
    mock_patient_data = json.load(reader)
    
acmg_codes = {
    '1': 'Benign',
    '2': 'Likely Benign',
    '3': 'Variant of Uncertain Significance',
    '4': 'Likely Pathogenic',
    '5': 'Pathogenic',
    'U': 'Unknown'
}
ranks = ['U', '1', '2', '3', '4', '5']

# %%
! pip install tabulate

# %%
filtered_transcripts_report_data = []
for allele_assessment in analysis_data['allele_assessments']:
    classification_int_code = allele_assessment['allele_assessment']['classification']
    allele_report = allele_assessment['allele_report']
    transcripts = allele_assessment['annotation']['transcripts']
    # This just gives the name of the filtered transcripts
    filtered_transcripts_ids = allele_assessment['annotation']['filtered_transcripts']
    filtered_transcripts_data =  list(filter(lambda n : n['transcript'] in filtered_transcripts_ids, transcripts))
    for n in filtered_transcripts_data:
        filtered_transcripts_report_data.append(n)
    allele_assessment['filterd_transcripts'] = filtered_transcripts_report_data
    
analysis_data['allele_assessments'][0]
# Out:
# {'allele_assessment': {'allele_id': 3,
#   'analysis_id': 2,
#   'annotation_id': 3,
#   'attachment_ids': [],
#   'classification': '4',
#   'custom_annotation_id': None,
#   'date_created': '2020-10-19T10:49:44.630277+00:00',
#   'date_superceeded': None,
#   'evaluation': {'acmg': {'included': [{'code': 'PVS1',
#       'comment': '',
#       'match': None,
#       'op': None,
#       'source': 'suggested',
#       'uuid': '5104d287-683d-4391-a75b-5694c65f2b88'},
#      {'code': 'PPxPM2',
#       'comment': '',
#       'match': None,
#       'op': None,
#       'source': 'suggested',
#       'uuid': 'b44315f8-2db9-4605-b824-acf51e50ac31'}],
#     'suggested': [{'code': 'REQ_GP_last_exon_not_important',
#       'match': ['LENI'],
#       'op': '$in',
#       'source': 'genepanel.last_exon_important'},
#      {'code': 'REQ_GP_LOF_missense',
#       'match': ['ANY'],
#       'op': '$in',
#       'source': 'genepanel.disease_mode'},
#      {'code': 'REQ_not_in_last_exon',
#       'match': ['no'],
#       'op': '$in',
#       'source': 'transcript.in_last_exon'},
#      {'code': 'REQ_null_variant',
#       'match': ['stop_gained'],
#       'op': '$in',
#       'source': 'transcript.consequences'},
#      {'code': 'REQ_no_freq',
#       'match': ['null_freq'],
#       'op': '$in',
#       'source': 'frequencies.commonness'},
#      {'code': 'PVS1', 'match': None, 'op': None, 'source': None},
#      {'code': 'PPxPM2', 'match': None, 'op': None, 'source': None}],
#     'suggested_classification': 4},
#    'classification': {'comment': ''},
#    'external': {'comment': ''},
#    'frequency': {'comment': ''},
#    'prediction': {'comment': ''},
#    'reference': {'comment': ''}},
#   'genepanel_name': 'HBOCUTV',
#   'genepanel_version': 'v01',
#   'id': 1,
#   'previous_assessment_id': None,
#   'seconds_since_update': 3447886.719649,
#   'user': {'abbrev_name': 'H. Ibsen',
#    'active': True,
#    'first_name': 'Henrik',
#    'full_name': 'Henrik Ibsen',
#    'id': 1,
#    'last_name': 'Ibsen',
#    'user_group_name': 'testgroup01',
#    'username': 'testuser1'},
#   'user_id': 1,
#   'usergroup': {'id': 1, 'name': 'testgroup01'},
#   'usergroup_id': 1},
#  'allele_report': {'allele_id': 3,
#   'analysis_id': 2,
#   'date_created': '2020-10-19T10:49:44.640931+00:00',
#   'date_superceeded': None,
#   'evaluation': {'comment': ''},
#   'id': 1,
#   'previous_report_id': None,
#   'seconds_since_update': 3447886.733316,
#   'user': {'abbrev_name': 'H. Ibsen',
#    'active': True,
#    'first_name': 'Henrik',
#    'full_name': 'Henrik Ibsen',
#    'id': 1,
#    'last_name': 'Ibsen',
#    'user_group_name': 'testgroup01',
#    'username': 'testuser1'},
#   'user_id': 1,
#   'usergroup': {'id': 1, 'name': 'testgroup01'},
#   'usergroup_id': 1},
#  'annotation': {'annotation_id': 3,
#   'external': {'CLINVAR': {'items': [{'clinical_significance_descr': 'Pathogenic',
#       'last_evaluated': '01/11/2017',
#       'rcv': 'SCV000296805',
#       'submitter': 'GeneKor MSA',
#       'traitnames': '',
#       'variant_id': ''},
#      {'clinical_significance_descr': 'Pathogenic',
#       'last_evaluated': '18/10/2016',
#       'rcv': 'SCV000323955',
#       'submitter': 'ENIGMA',
#       'traitnames': '',
#       'variant_id': ''},
#      {'clinical_significance_descr': 'Pathogenic',
#       'last_evaluated': '18/10/2016',
#       'rcv': 'RCV000257718',
#       'submitter': '',
#       'traitnames': 'Breast-ovarian cancer, familial 2',
#       'variant_id': '51063'},
#      {'clinical_significance_descr': 'Pathogenic',
#       'last_evaluated': '01/11/2017',
#       'rcv': 'RCV000239090',
#       'submitter': '',
#       'traitnames': 'not provided',
#       'variant_id': '51063'},
#      {'clinical_significance_descr': 'Pathogenic',
#       'last_evaluated': '02/10/2015',
#       'rcv': 'SCV000326495',
#       'submitter': 'CIMBA',
#       'traitnames': '',
#       'variant_id': ''}],
#     'variant_description': 'reviewed by expert panel',
#     'variant_id': 51063},
#    'HGMD': {'acc_num': 'CM082514',
#     'codon': 4,
#     'disease': 'Breast and/or ovarian cancer',
#     'tag': 'DM'}},
#   'filtered_transcripts': ['NM_000059.3'],
#   'frequencies': {},
#   'prediction': {},
#   'references': [{'pubmed_id': 17453335,
#     'source_info': {'HGMD': 'Primary literature report. No comments.'},
#     'sources': ['HGMD']}],
#   'schema_version': 1,
#   'transcripts': [{'HGVSc': 'c.10G>T',
#     'HGVSc_short': 'c.10G>T',
#     'HGVSp': 'p.Gly4Ter',
#     'amino_acids': 'G/*',
#     'coding_region_distance': 0,
#     'codons': 'Gga/Tga',
#     'consequences': ['stop_gained'],
#     'dbsnp': ['rs397507571'],
#     'exon': '2/27',
#     'exon_distance': 0,
#     'hgnc_id': 1101,
#     'in_last_exon': 'no',
#     'is_canonical': True,
#     'protein': 'NP_000050.2',
#     'strand': 1,
#     'symbol': 'BRCA2',
#     'transcript': 'NM_000059.3'},
#    {'consequences': ['upstream_gene_variant'],
#     'dbsnp': ['rs397507571'],
#     'hgnc_id': 37116,
#     'in_last_exon': 'no',
#     'is_canonical': True,
#     'strand': -1,
#     'symbol': 'ZAR1L',
#     'transcript': 'NM_001136571.1'}],
#   'worst_consequence': ['NM_000059.3']},
#  'change_from': 'G',
#  'change_to': 'T',
#  'change_type': 'SNP',
#  'chromosome': '13',
#  'genome_reference': 'GRCh37',
#  'id': 3,
#  'open_end_position': 32890607,
#  'samples': [{'affected': True,
#    'date_deposited': '2020-10-19T10:46:43.434024+00:00',
#    'family_id': None,
#    'father_id': None,
#    'genotype': {'allele_depth': {'REF (G)': 107, 'T': 80},
#     'allele_ratio': 0.42780748663101603,
#     'filter_status': 'PASS',
#     'formatted': 'G/T',
#     'genotype_quality': 99,
#     'id': 3,
#     'multiallelic': False,
#     'needs_verification': False,
#     'needs_verification_checks': {'allele_ratio': True,
#      'dp': True,
#      'hts': True,
#      'pass': True,
#      'snp': True},
#     'sequencing_depth': 187,
#     'type': 'Heterozygous',
#     'variant_quality': 5000},
#    'id': 2,
#    'identifier': 'brca_sample_1',
#    'mother_id': None,
#    'proband': True,
#    'sample_type': 'HTS',
#    'sex': None,
#    'sibling_id': None}],
#  'start_position': 32890606,
#  'tags': ['has_references'],
#  'vcf_alt': 'T',
#  'vcf_pos': 32890607,
#  'vcf_ref': 'G',
#  'filterd_transcripts': [{'HGVSc': 'c.10G>T',
#    'HGVSc_short': 'c.10G>T',
#    'HGVSp': 'p.Gly4Ter',
#    'amino_acids': 'G/*',
#    'coding_region_distance': 0,
#    'codons': 'Gga/Tga',
#    'consequences': ['stop_gained'],
#    'dbsnp': ['rs397507571'],
#    'exon': '2/27',
#    'exon_distance': 0,
#    'hgnc_id': 1101,
#    'in_last_exon': 'no',
#    'is_canonical': True,
#    'protein': 'NP_000050.2',
#    'strand': 1,
#    'symbol': 'BRCA2',
#    'transcript': 'NM_000059.3'},
#   {'HGVSc': 'c.51_52delAC',
#    'HGVSc_short': 'c.51_52delAC',
#    'HGVSp': 'p.Arg18LeufsTer12',
#    'amino_acids': 'T/X',
#    'coding_region_distance': 0,
#    'codons': 'ACa/a',
#    'consequences': ['frameshift_variant'],
#    'exon': '2/27',
#    'exon_distance': 0,
#    'hgnc_id': 1101,
#    'in_last_exon': 'no',
#    'is_canonical': True,
#    'protein': 'NP_000050.2',
#    'strand': 1,
#    'symbol': 'BRCA2',
#    'transcript': 'NM_000059.3'},
#   {'HGVSc': 'c.67+2T>A',
#    'HGVSc_short': 'c.67+2T>A',
#    'coding_region_distance': None,
#    'consequences': ['splice_donor_variant'],
#    'dbsnp': ['rs81002885'],
#    'exon_distance': 2,
#    'hgnc_id': 1101,
#    'in_last_exon': 'no',
#    'intron': '2/26',
#    'is_canonical': True,
#    'strand': 1,
#    'symbol': 'BRCA2',
#    'transcript': 'NM_000059.3'},
#   {'HGVSc': 'c.72A>T',
#    'HGVSc_short': 'c.72A>T',
#    'HGVSp': 'p.Leu24Phe',
#    'amino_acids': 'L/F',
#    'coding_region_distance': 0,
#    'codons': 'ttA/ttT',
#    'consequences': ['missense_variant'],
#    'dbsnp': ['rs397507909'],
#    'exon': '3/27',
#    'exon_distance': 0,
#    'hgnc_id': 1101,
#    'in_last_exon': 'no',
#    'is_canonical': True,
#    'protein': 'NP_000050.2',
#    'strand': 1,
#    'symbol': 'BRCA2',
#    'transcript': 'NM_000059.3'},
#   {'HGVSc': 'c.97G>T',
#    'HGVSc_short': 'c.97G>T',
#    'HGVSp': 'p.Glu33Ter',
#    'amino_acids': 'E/*',
#    'coding_region_distance': 0,
#    'codons': 'Gaa/Taa',
#    'consequences': ['stop_gained'],
#    'dbsnp': ['rs397508065'],
#    'exon': '3/27',
#    'exon_distance': 0,
#    'hgnc_id': 1101,
#    'in_last_exon': 'no',
#    'is_canonical': True,
#    'protein': 'NP_000050.2',
#    'strand': 1,
#    'symbol': 'BRCA2',
#    'transcript': 'NM_000059.3'},
#   {'HGVSc': 'c.198A>G',
#    'HGVSc_short': 'c.198A>G',
#    'HGVSp': 'c.198A>G(p.=)',
#    'amino_acids': 'Q',
#    'coding_region_distance': 0,
#    'codons': 'caA/caG',
#    'consequences': ['synonymous_variant'],
#    'dbsnp': ['rs28897700'],
#    'exon': '3/27',
#    'exon_distance': 0,
#    'hgnc_id': 1101,
#    'in_last_exon': 'no',
#    'is_canonical': True,
#    'protein': 'NM_000059.3',
#    'strand': 1,
#    'symbol': 'BRCA2',
#    'transcript': 'NM_000059.3'}]}

# %%
# We are assuming we only need data for the first sample!
columns = ['Gene', 'Variant', 'Zygosity', 'Variant Classification']

# We also need to rank the variants and go for the most conservative classification
gene_data = []
for allele_assessment in analysis_data['allele_assessments']:
    transcripts = allele_assessment['filterd_transcripts']
    for transcript in transcripts:
        d = {
            'Gene': transcript['symbol'],
            'Variant': transcript['HGVSc'],
            'Zygosity': allele_assessment['samples'][0]['genotype']['type'],
            'Variant Classification': acmg_codes[str(allele_assessment['allele_assessment']['classification'])],
            'Variant Classification Code': allele_assessment['allele_assessment']['classification']
        }
        gene_data.append(d)

#print(gene_data)
import random
random.shuffle(gene_data)
gene_data
df = pd.DataFrame.from_records(gene_data)

df = df.drop_duplicates()
df
#df['Variant Classififica']
# Out:
#      Gene       Variant      Zygosity Variant Classification  \
# 0   BRCA2       c.10G>T  Heterozygous      Likely Pathogenic
# 1   BRCA2      c.198A>G  Heterozygous      Likely Pathogenic
# 2   BRCA2       c.97G>T  Heterozygous      Likely Pathogenic
# 3   BRCA2       c.72A>T  Heterozygous                Unknown
# 4   BRCA2     c.67+2T>A  Heterozygous                Unknown
# 5   BRCA2       c.72A>T  Heterozygous      Likely Pathogenic
# 7   BRCA2       c.10G>T  Heterozygous                Unknown
# 9   BRCA2  c.51_52delAC  Heterozygous                Unknown
# 15  BRCA2       c.97G>T  Heterozygous                Unknown
# 17  BRCA2  c.51_52delAC  Heterozygous      Likely Pathogenic
# 18  BRCA2     c.67+2T>A  Heterozygous      Likely Pathogenic
# 23  BRCA2      c.198A>G  Heterozygous                Unknown
#
#    Variant Classification Code
# 0                            4
# 1                            4
# 2                            4
# 3                            U
# 4                            U
# 5                            4
# 7                            U
# 9                            U
# 15                           U
# 17                           4
# 18                           4
# 23                           U

# %%
# We also need to rank the variants and go for the most conservative classification
# I think this will work, but it should be tested more

df = df.sort_values(by=['Variant Classification Code'], key=lambda x: x.map(acmg_codes))
df = df.drop_duplicates(subset=['Variant'])
df.drop(columns=['Variant Classification Code'])
df
# Out:
#      Gene       Variant      Zygosity Variant Classification  \
# 0   BRCA2       c.10G>T  Heterozygous      Likely Pathogenic
# 1   BRCA2      c.198A>G  Heterozygous      Likely Pathogenic
# 2   BRCA2       c.97G>T  Heterozygous      Likely Pathogenic
# 5   BRCA2       c.72A>T  Heterozygous      Likely Pathogenic
# 17  BRCA2  c.51_52delAC  Heterozygous      Likely Pathogenic
# 18  BRCA2     c.67+2T>A  Heterozygous      Likely Pathogenic
#
#    Variant Classification Code
# 0                            4
# 1                            4
# 2                            4
# 5                            4
# 17                           4
# 18                           4

# %%
from tabulate import tabulate
markdown_table_str = tabulate(df, headers='keys', tablefmt='pipe', showindex=False)
mock_patient_data['markdown_table_str'] = markdown_table_str

# %%
from jinja2 import Environment, BaseLoader


report_header_table = """
# Report

## Sample-1

---

|  |  |  |  |
| --- | --- | --- | --- |
| **Patient Name:** | {{ patient_data.patient_last_name }}, {{ patient_data.patient_first_name }} | **Ordered By:** | {{test_data.test_requesting_physician}} |
| **Date of Birth:** | {{patient_data.patient_dob}} | **Sample Collection Date:** | {{ sample_data.sample_collection_date }} | 
| **Gender**: | {{patient_data.patient_gender}} | **Sample Accession Date:** | {{ sample_data.sample_accession_date }} |
| **Sample Type:** | {{sample_data.sample_type}} | **Report Data:** | {{report_data.report_date}} |
| **Sample ID/MRN:** | {{ sample_data.sample_id }} | | |
| **Test Accession:** | {{ test_data.test_accession }} | | | 
| **Test Ordered:** | {{test_data.test_ordered}} | | | 
| **Test Code:** | {{ test_data.test_code }} | | |
| **Test Indictation** | {{ test_data.test_indication }} | | |

---

## Result: Postitive

---

{{ markdown_table_str }}

"""

rtemplate = Environment(loader=BaseLoader()).from_string(report_header_table)
rendered_report_header_table = rtemplate.render(**mock_patient_data)
print(rendered_report_header_table)
# Out:
# # Report
#
# ## Sample-1
#
# ---
#
# |  |  |  |  |
# | --- | --- | --- | --- |
# | **Patient Name:** | Smith, Todd | **Ordered By:** | Dr. Who |
# | **Date of Birth:** | 12/11/1977 | **Sample Collection Date:** | 12/9/2020 |
# | **Gender**: | Male | **Sample Accession Date:** | 12/9/2020 |
# | **Sample Type:** | blood | **Report Data:** | 12/9/2020 |
# | **Sample ID/MRN:** | 1234567 | | |
# | **Test Accession:** | BRCA122345 | | |
# | **Test Ordered:** | BRCA2 sequencing & Deletion/Duplication analysis | | |
# | **Test Code:** | ABCD | | |
# | **Test Indictation** | Patient has family history of breast cancer. | | |
#
# ---
#
# ## Result: Postitive
#
# ---
#
# | Gene   | Variant      | Zygosity     | Variant Classification   |
# |:-------|:-------------|:-------------|:-------------------------|
# | BRCA2  | c.10G>T      | Heterozygous | Likely Pathogenic        |
# | BRCA2  | c.51_52delAC | Heterozygous | Likely Pathogenic        |
# | BRCA2  | c.67+2T>A    | Heterozygous | Likely Pathogenic        |
# | BRCA2  | c.72A>T      | Heterozygous | Likely Pathogenic        |
# | BRCA2  | c.97G>T      | Heterozygous | Likely Pathogenic        |
# | BRCA2  | c.198A>G     | Heterozygous | Likely Pathogenic        |

# %%
# This doesn't work in the jupyterhub output
from IPython.display import display, Markdown, Latex, HTML
display(Markdown(rendered_report_header_table))
# Out:
# # Report
#
# ## Sample-1
#
# ---
#
# |  |  |  |  |
# | --- | --- | --- | --- |
# | **Patient Name:** | Smith, Todd | **Ordered By:** | Dr. Who |
# | **Date of Birth:** | 12/11/1977 | **Sample Collection Date:** | 12/9/2020 |
# | **Gender**: | Male | **Sample Accession Date:** | 12/9/2020 |
# | **Sample Type:** | blood | **Report Data:** | 12/9/2020 |
# | **Sample ID/MRN:** | 1234567 | | |
# | **Test Accession:** | BRCA122345 | | |
# | **Test Ordered:** | BRCA2 sequencing & Deletion/Duplication analysis | | |
# | **Test Code:** | ABCD | | |
# | **Test Indictation** | Patient has family history of breast cancer. | | |
#
# ---
#
# ## Result: Postitive
#
# ---
#
# | Gene   | Variant      | Zygosity     | Variant Classification   |
# |:-------|:-------------|:-------------|:-------------------------|
# | BRCA2  | c.10G>T      | Heterozygous | Likely Pathogenic        |
# | BRCA2  | c.51_52delAC | Heterozygous | Likely Pathogenic        |
# | BRCA2  | c.67+2T>A    | Heterozygous | Likely Pathogenic        |
# | BRCA2  | c.72A>T      | Heterozygous | Likely Pathogenic        |
# | BRCA2  | c.97G>T      | Heterozygous | Likely Pathogenic        |
# | BRCA2  | c.198A>G     | Heterozygous | Likely Pathogenic        |
